# %% [markdown]
# # Single map correction using DF functions and comparison with old functions

# %% [markdown]
# ## Scope
#
# - This NB computes XY maps using run 6861 to correct energy and
# lifetime.
#
# - Voltage in the anode 7.7 kV!
# - New DAQ, lower PMT gain.
#
# - ENRICHED XENON! Krypton calibration with high krypton rate
#
# - It uses DF functions (functions which take a DF map rather than a KrEvent) and compares with old functions

# %% [markdown]
# ### Author:  JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/ICAROS/

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
import warnings
import datetime 
print("Last updated on ", time.asctime())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Last updated on  Tue Feb 12 00:15:20 2019

# %% [markdown]
# ### Logger

# %%
import logging


logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)

logging.info('Hello world!')
# Out:
# 2019-02-11 09:37:16,221 | INFO : Hello world!

# %% [markdown]
# ### Input files

# %%
from krcal.core.kr_types import KrFileName
input_path  = f"$IC_DATA/dst"
output_path = f"$IC_DATA/ldst"
map_path    = f"$IC_DATA/maps"


run_number  = 6880
first_file  ='0000'
last_file   = 6944
input_file_names  = [f'dst_{run_number}_trigger1_{first_file}_{last_file}.h5']

time_bins = 5
output_file_name  = ' '
map_file_name     = ''
map_file_name_ts  = ''
emap_file_name    = f'kr_emap_xy_100_100_r_{run_number}.h5'


krfn = KrFileName(input_file_names,
                  output_file_name,
                  map_file_name,
                  map_file_name_ts,
                  emap_file_name)

# %% [markdown]
# ### Notebook configuration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from matplotlib.patches import Circle, Wedge, Polygon
from matplotlib.collections import PatchCollection

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib
import tables            as tb
import random
import glob
import warnings
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
from  invisible_cities.core.system_of_units_c import units
import invisible_cities.reco.corrections      as corrf

# %%
from krcal.core.io_functions       import kdst_write
from krcal.core.io_functions       import filenames_from_list
from krcal.core.io_functions       import write_maps
from krcal.core.io_functions       import read_maps
from krcal.core.io_functions       import write_maps_ts
from krcal.core.io_functions       import read_maps_ts

# %%
from krcal.core.histo_functions    import h1, h1d, h2, h2d, plot_histo

# %%
from krcal.core.core_functions      import time_delta_from_time
from krcal.core.core_functions      import phirad_to_deg
from krcal.core.core_functions      import NN
from krcal.core.core_functions      import timeit
from krcal.core.core_functions  import data_frames_are_identical
from krcal.core                     import fit_functions_ic as fitf

# %%
from krcal.core.plt_functions  import plot_sector
from krcal.core.plt_functions  import plot_sectors

# %%
from krcal.core.stat_functions      import mean_and_std

# %%
from krcal.core.analysis_functions  import kr_ranges_and_bins
from krcal.core.analysis_functions  import fiducial_volumes
from krcal.core.analysis_functions  import fid_eff
from krcal.core.analysis_functions  import select_rphi_sectors
from krcal.core.analysis_functions  import select_xy_sectors
from krcal.core.analysis_functions  import kr_event_selection
from krcal.core.analysis_functions  import kr_event

# %%
from krcal.core.fit_lt_functions    import fit_lifetime
from krcal.core.fit_lt_functions    import time_fcs
from krcal.core.fit_lt_functions    import fit_fcs_in_rphi_sectors
from krcal.core.fit_lt_functions    import fit_fcs_in_xy_bin
from krcal.core.fit_lt_functions    import fit_map_rphi
from krcal.core.fit_lt_functions    import fit_map_xy
from krcal.core.fit_lt_functions    import get_time_series

# %%
from krcal.core.fit_lt_histograms   import histo_fit_sectors
from krcal.core.fit_lt_histograms   import print_fit_sectors_pars
from krcal.core.fit_lt_histograms   import plot_fit_sectors
from krcal.core.fit_lt_histograms   import plot_fit_xy
from krcal.core.fit_lt_histograms   import plot_time_fcs
from krcal.core.fit_lt_histograms   import plot_fit_lifetime_and_chi2
from krcal.core.fit_lt_histograms   import print_fit_lifetime

# %%
from krcal.core.fit_energy_functions    import fit_energy
from krcal.core.fit_energy_functions    import plot_fit_energy
from krcal.core.fit_energy_functions    import print_fit_energy
from krcal.core.fit_energy_functions    import resolution_r_z
from krcal.core.fit_energy_functions    import plot_resolution_r_z

# %%
from krcal.core.kr_types import PlotLabels, KrEvent, ASectorMap
from krcal.core.kr_types import FitType, KrSector, MapType
from krcal.core.kr_types import KrFileName
from krcal.core.kr_types import ASectorMap

# %%
from krcal.core.rphi_maps_functions   import draw_rphi_maps
from krcal.core.rphi_maps_functions   import draw_rphi_map
from krcal.core.rphi_maps_functions   import draw_rphi_maps_ts
from krcal.core.rphi_maps_functions   import draw_wedges
from krcal.core.rphi_maps_functions   import define_rphi_sectors
from krcal.core.rphi_maps_functions   import rphi_sector_map_def

# %%
from krcal.core.map_functions   import tsmap_from_fmap
from krcal.core.map_functions   import amap_from_tsmap
from krcal.core.map_functions   import relative_errors
from krcal.core.map_functions   import amap_valid_mask
from krcal.core.map_functions   import amap_valid_fraction
from krcal.core.map_functions   import amap_average
from krcal.core.map_functions   import amap_max
from krcal.core.map_functions   import amap_min
from krcal.core.map_functions   import amap_replace_nan_by_mean
from krcal.core.map_functions   import amap_replace_nan_by_zero
from krcal.core.map_functions   import regularize_maps
from krcal.core.map_functions   import get_maps_from_tsmap
from krcal.core.map_functions   import map_average
from krcal.core.map_functions   import add_mapinfo

# %%
from krcal.core.xy_maps_functions   import draw_xy_maps
from krcal.core.xy_maps_functions   import draw_xy_map
from krcal.core.xy_maps_functions   import draw_xy_maps_ts

# %%
from krcal.core.s1s2_functions  import energy_time_profile
from krcal.core.s1s2_functions  import energy_X_profile

# %%
from krcal.core.correction_functions import e0_rphi_correction
from krcal.core.correction_functions import e0_xy_correction
from krcal.core.correction_functions import lt_xy_correction
from krcal.core.correction_functions import e0_xy_correction_ts
from krcal.core.correction_functions import lt_xy_correction_ts
from krcal.core.correction_functions import lt_rphi_correction
from krcal.core.correction_functions import lt_rphi_correction_ts
from krcal.core.correction_functions import e0_rphi_correction_ts
from krcal.core.correction_functions import e0_rphi_correction_ts

# %%
from krcal.core.selection_functions  import event_map_df
from krcal.core.selection_functions  import select_rphi_sectors_df
from krcal.core.selection_functions  import select_xy_sectors_df
from krcal.core.selection_functions  import get_time_series_df
from krcal.core.fitmap_functions     import time_fcs_df
from krcal.core.fitmap_functions     import fit_fcs_in_rphi_sectors_df
from krcal.core.fitmap_functions     import fit_map_xy_df

# %%
import krcal.dev.corrections       as corrections

# %%
from numpy import pi, sqrt

# %%
from typing      import List, Tuple, Dict, Sequence, Iterable

# %%
import cProfile

# %% [markdown]
# ### Logger
#
#
# - CRITICAL
# - ERROR
# - WARNING
# - INFO
# - DEBUG

# %%
import logging
log = logging.getLogger()

# %% [markdown]
# ### Input/output

# %%
fn =filenames_from_list(krfn, input_path, output_path, map_path)

# %%
fn
# Out:
# KrFileName(input_file_names=['/Users/jjgomezcadenas/Projects/ICDATA/dst/dst_6880_trigger1_0000_6944.h5'], output_file_name='/Users/jjgomezcadenas/Projects/ICDATA/ldst/ ', map_file_name='/Users/jjgomezcadenas/Projects/ICDATA/maps/', map_file_name_ts='/Users/jjgomezcadenas/Projects/ICDATA/maps/', emap_file_name='/Users/jjgomezcadenas/Projects/ICDATA/maps/kr_emap_xy_100_100_r_6880.h5')

# %%
dst           = load_dsts(fn.input_file_names, "DST", "Events")

# %%
unique_events = ~dst.event.duplicated()
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of events: {len(dst)}")
# Out:
# Total number of events: 1091202

# %%
dst.columns
# Out:
# Index(['index', 'event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w',
#        'S1h', 'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT',
#        'Z', 'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %% [markdown]
# ### Ranges and binning

# %%
RMAX      = 200
RCORE     = 100
s1e_range = (3, 25)
s2e_range = (2000, 14000)
s2q_range = (200, 800)

xy_range  = (-RMAX,  RMAX)
z_range   = (10,  550)
e_range = (5000, 14000)
lt_range = (1000, 6000)
c2_range = (0,5)

krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = xy_range,
                                                        yrange    = xy_range,
                                                        zrange    = z_range,
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = 100,
                                                        ynbins    = 100,
                                                        znbins    = 15,
                                                        s2enbins  = 25,
                                                        s1enbins  = 10,
                                                        s2qnbins  = 25,
                                                        tpsamples = 3600) # tsamples in seconds

# %%
krRanges
# Out:
# KrRanges(S2e=(2000, 14000), S1e=(3, 25), S2q=(200, 800), X=(-200, 200), Y=(-200, 200), Z=(10, 550), T=(1549645558.135, 1549707233.558))

# %%
krNbins
# Out:
# KrNBins(S2e=25, S1e=10, S2q=25, X=100, Y=100, Z=15, T=17)

# %% [markdown]
# ### Define fiducial cut (R < 200 mm)

# %%
dstFid = dst[in_range(dst.R, 0, RMAX)]

# %% [markdown]
# ### Sort DST in time and add DT column (DT is a vector of time differences)

# %%
dst_time = dstFid.sort_values('time')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %%
dst = dst_time.assign(DT=DT)

# %%
dst.columns
# Out:
# Index(['index', 'event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w',
#        'S1h', 'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT',
#        'Z', 'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)  # kge = krypton general event; it simply selects a krEvent from the existing DST

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(dst.DT.values, bins=500, range = (dst.DT.values[0], dst.DT.values[-1]), color='red', stats=False, lbl='pre-sel')

# %% [markdown]
# #### Variable rate from Krypton

# %% [markdown]
# ### Time

# %%
plt.plot(krTimes.timeStamps)

# %% [markdown]
# ### Event distribution

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# ## Time series

# %% [markdown]
# #### Run in debug mode, to view the time series and indexes

# %%
log.setLevel(logging.DEBUG)

# %%
ts, masks = get_time_series_df(time_bins, (DT[0],DT[-1]), dst)

# %% [markdown]
# #### Check that get_time_series and get_time_series_df give the same result

# %%
ts2, masks2 = get_time_series(time_bins, (DT[0],DT[-1]), kge)
# Out:
# 2019-02-15 17:42:43,227 | DEBUG : function: get_time_series
# 2019-02-15 17:42:43,235 | DEBUG :  number of time bins = 5, t_first = 0 t_last = 61675
# 2019-02-15 17:42:43,235 | DEBUG : indx = [(0, 12335), (12335, 24670), (24670, 37005), (37005, 49340), (49340, 61675)]
# 2019-02-15 17:42:43,236 | DEBUG : ts = [6167.5, 18502.5, 30837.5, 43172.5, 55507.5]

# %%
np.array(masks).all() == np.array(masks2).all()
# Out:
# True

# %%
#### Rerun in normal mode, with time info

# %%
log.setLevel(logging.INFO)

# %%
ti = timeit(get_time_series_df)
ts, masks = ti(time_bins, (DT[0],DT[-1]), dst)
# Out:
# Time spent in get_time_series_df: 0.013036251068115234 s

# %% [markdown]
# ### Fit lifetime of the time series in the full detector.

# %%
ti = timeit(time_fcs)
fps = ti(ts, masks, kge, 
         nbins_z = 15,
         nbins_e = 25,
         range_z = (10, 550),
         range_e = (7000, 14000),
         energy  = 'S2e',
         fit     = FitType.profile)  # fps: fit-profile series (implicit is a time series, using profile)
# Out:
# Time spent in time_fcs: 0.24191784858703613 s

# %%
plot_time_fcs(fps,
              range_chi2  = (0,10),
              range_e0    = (7000,12000),
              range_lt    = (1000, 8000),
              figsize     = (12,6))

# %%
ti = timeit(time_fcs_df)
fps = ti(ts, masks, dst, 
         nbins_z = 15,
         nbins_e = 25,
         range_z = (10, 550),
         range_e = (7000, 14000),
         energy  = 'S2e',
         fit     = FitType.profile)  # fps: fit-profile series (implicit is a time series, using profile)
# Out:
# Time spent in time_fcs_df: 0.2678561210632324 s

# %%
plot_time_fcs(fps,
              range_chi2  = (0,10),
              range_e0    = (7000,12000),
              range_lt    = (1000, 8000),
              figsize     = (12,6))

# %% [markdown]
# #### Repeat using unbined fitting

# %%
fus = ti(ts, masks, dst, 
         nbins_z = 15,
         nbins_e = 25,
         range_z = (10, 550),
         range_e = (7000, 14000),
         energy  = 'S2e',
         fit     = FitType.unbined)  # fus: fit-unbined series (implicit is a time series, using unbined)
# Out:
# Time spent in time_fcs_df: 0.35598301887512207 s

# %%
plot_time_fcs(fus,
              range_chi2  = (0,10),
              range_e0    = (7000,12000),
              range_lt    = (1000, 8000),
              figsize     = (12,6))

# %% [markdown]
# ## Lifetime in RPhi

# %% [markdown]
# #### To compute a RPHI map, the first step is to define a KrSector map which contains the definition of the RPHI wedges:

# %%
NSECTORS =5  # number of sectors in R. Each sector then is 200 / 5 = 40 cm.
SPHI     =45 # size of the phi pie-slice in degrees, thus 10 slices in phi.

# %%
rpsmd = rphi_sector_map_def(nSectors=NSECTORS, rmax=RMAX, sphi=SPHI)

# %%
W = define_rphi_sectors(rpsmd)

# %%
draw_wedges(W,  rmax = RMAX, 
            scale= 0.49, figsize=(10,8), alpha=1.0,
            cr =range(NSECTORS))

# %% [markdown]
# #### The next step is to select the RPHI sectors than enter the map.

# %%
ti = timeit(select_rphi_sectors)
KSRP = ti(dst, DT, dst.S2e, dst.S2q, W) # KSRP: Krypton Selection R-PHI
# Out:
# Time spent in select_rphi_sectors: 1.2704880237579346 s

# %%
type(KSRP[0][0])
# Out:
# krcal.core.kr_types.KrEvent

# %%
ti = timeit(event_map)
neM = ti(KSRP)   # number of events in Map
# Out:
# Time spent in event_map: 0.0007009506225585938 s

# %%
neM
# Out:
#       0      1      2      3      4
# 0  5435  17890  30156  41499  48546
# 1  5643  17500  28605  41815  48046
# 2  5634  16482  27590  40959  47170
# 3  5258  16673  27272  38287  46487
# 4  5455  16026  28478  35085  46009
# 5  5857  16942  25907  38603  39256
# 6  6092  18324  29805  41377  41195
# 7  5640  16380  29502  40858  45226

# %%
ti = timeit(select_rphi_sectors_df)
KSRP2 = ti(dst, W) # KSRP: Krypton Selection R-PHI
# Out:
# Time spent in select_rphi_sectors_df: 0.98248291015625 s

# %%
type(KSRP2[0][0])
# Out:
# pandas.core.frame.DataFrame

# %%
ti = timeit(event_map_df)
neM2 = ti(KSRP2)
# Out:
# Time spent in event_map_df: 0.0007188320159912109 s

# %%
data_frames_are_identical(neM, neM2)
# Out:
# True

# %% [markdown]
# #### The number of events in the map can be represented by a heat map

# %%
ax = sns.heatmap(neM, square=True)

# %% [markdown]
# ### One can now fit the lifetime in RPHI sectors (in time bins)

# %%
erange = (0,14000)
ltrange = (0, 7000)
# frs --> fit radial sectors

# %%
ti = timeit(fit_fcs_in_rphi_sectors)
for sector in range(NSECTORS):
    frs = ti(sector = sector, selection_map=KSRP, event_map=neM, n_time_bins=time_bins, time_diffs=DT,
                                  nbins_z       = 25,
                                  nbins_e       = 50,
                                  range_z       =(50, 550),
                                  range_e       = (5000, 14500),
                                  energy        = 'S2e',
                                  fit           = FitType.unbined,
                                  n_min         = 100)
# Out:
# Time spent in fit_fcs_in_rphi_sectors: 0.12666821479797363 s
# Time spent in fit_fcs_in_rphi_sectors: 0.14175200462341309 s
# Time spent in fit_fcs_in_rphi_sectors: 0.15608596801757812 s
# Time spent in fit_fcs_in_rphi_sectors: 0.17316293716430664 s
# Time spent in fit_fcs_in_rphi_sectors: 0.18156981468200684 s

# %%
ti = timeit(fit_fcs_in_rphi_sectors_df)
for sector in range(NSECTORS):
    frs2 = ti(sector = sector,
              selection_map = KSRP2,
              event_map     = neM,
              n_time_bins   = time_bins,
              time_diffs    = DT,
              nbins_z       = 25,
              nbins_e       = 50,
              range_z       =(50, 550),
              range_e       = (5000, 14500),
              energy        = 'S2e',
              fit           = FitType.unbined,
              n_min         = 100)

    plot_fit_sectors(frs2,  range_e0 =erange, range_lt=ltrange)
# Out:
# Time spent in fit_fcs_in_rphi_sectors_df: 0.15750813484191895 s
# Time spent in fit_fcs_in_rphi_sectors_df: 0.15479683876037598 s
# Time spent in fit_fcs_in_rphi_sectors_df: 0.17244291305541992 s
# Time spent in fit_fcs_in_rphi_sectors_df: 0.20206022262573242 s
# Time spent in fit_fcs_in_rphi_sectors_df: 0.19644808769226074 s

# %%
len(frs) == len(frs2)
# Out:
# True

# %%
for i, _ in enumerate(frs):
    fp = frs[i]
    fp2 = frs2[i]
    assert np.allclose(fp.ts, fp2.ts, rtol=1e-04, atol=1e-04)
    assert np.allclose(fp.e0, fp2.e0, rtol=1e-04, atol=1e-04)
    assert np.allclose(fp.lt, fp2.lt, rtol=1e-03, atol=1e-03)

# %% [markdown]
# ## Single time XY map.
#
# - Compute a single-time (or time-averaged) map, with a fine-grain in XY.
# - The energy map (e0 correction) is invariant and can be added for many maps.
# - The lt map (lt correction) represents an average-over-run. A correction function may use such a map or add a time-dependent correction, fitting the time dependence.

# %% [markdown]
# ## Divide chamber in sectors of XY

# %%
log.setLevel(logging.INFO) # turn to DEBUG to follow progress of this part

# %%
ti = timeit(select_xy_sectors)
KXY = ti(dst, DT, dst.S2e.values, dst.S2q.values, krBins.X, krBins.Y)
# Out:
# Time spent in select_xy_sectors: 54.2173810005188 s

# %%
log.setLevel(logging.INFO)

# %%
nXY = event_map(KXY)

# %%
ax = sns.heatmap(nXY, square=True)

# %%
ti = timeit(select_xy_sectors_df)
KXY2 = ti(dst, krBins.X, krBins.Y)
# Out:
# Time spent in select_xy_sectors_df: 9.323489904403687 s

# %%
nXY2 = event_map_df(KXY2)

# %%
ax = sns.heatmap(nXY2, square=True)

# %%
data_frames_are_identical(nXY, nXY2)
# Out:
# True

# %% [markdown]
# ## Fits in XY sectors

# %% [markdown]
# ## Maps

# %% [markdown]
# #### The first step is to fit a map XY (in time series) for the number of time bins required (in this case 1)

# %%
ti = timeit(fit_map_xy)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fmxy = ti(selection_map = KXY,
              event_map     = nXY,
              n_time_bins   = 1,
              time_diffs    = DT,
              nbins_z        = krNbins.Z, 
              nbins_e        = krNbins.S2e, 
              range_z        = z_range, 
              range_e        = e_range,
              energy        = 'S2e',
              fit           = FitType.unbined,
              n_min         = 100)
# Out:
# Time spent in fit_map_xy: 20.845612049102783 s

# %%
ti = timeit(fit_map_xy_df)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fmxy2 = ti(selection_map = KXY2,
              event_map     = nXY2,
              n_time_bins   = 1,
              time_diffs    = DT,
              nbins_z        = krNbins.Z, 
              nbins_e        = krNbins.S2e, 
              range_z        = z_range, 
              range_e        = e_range,
              energy        = 'S2e',
              fit           = FitType.unbined,
              n_min         = 100)
# Out:
# Time spent in fit_map_xy_df: 28.312893867492676 s

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cProfile.run("fit_map_xy(KXY, nXY, 1, DT, krNbins.Z, krNbins.S2e, z_range, e_range, 'S2e', FitType.unbined, 100)")
# Out:
#          37525606 function calls (37118093 primitive calls) in 28.253 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    363850    0.169    0.000    0.446    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#     72770    0.051    0.000    0.075    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.019    0.019   28.283   28.283 <string>:1(<module>)
#     10000    0.007    0.000    0.007    0.000 <string>:1(__init__)
#     14554    0.006    0.000    0.011    0.000 <string>:1(__new__)
#    151880    0.050    0.000    0.079    0.000 __init__.py:1361(debug)
#    151880    0.029    0.000    0.029    0.000 __init__.py:1619(isEnabledFor)
#    151880    0.128    0.000    0.220    0.000 __init__.py:1996(debug)
#     58216    0.040    0.000    0.067    0.000 __init__.py:205(iteritems)
#     14554    0.030    0.000    2.490    0.000 _decorators.py:136(wrapper)
#      7277    0.003    0.000    0.064    0.000 _methods.py:34(_sum)
#     14554    0.007    0.000    0.078    0.000 _methods.py:42(_any)
#     29108    0.025    0.000    0.025    0.000 _validators.py:114(_check_for_invalid_keys)
#     29108    0.033    0.000    0.072    0.000 _validators.py:130(validate_kwargs)
#     29108    0.010    0.000    0.010    0.000 _validators.py:32(_check_for_default_values)
#    203756    0.065    0.000    0.151    0.000 abc.py:137(__instancecheck__)
#     14554    0.042    0.000    0.526    0.000 algorithms.py:141(_reconstruct_data)
#     14554    0.017    0.000    0.025    0.000 algorithms.py:1421(_get_take_nd_function)
#     14554    0.112    0.000    0.806    0.000 algorithms.py:1548(take_nd)
#     14554    0.007    0.000    0.054    0.000 algorithms.py:172(_ensure_arraylike)
#     14554    0.018    0.000    0.146    0.000 algorithms.py:224(_get_data_algo)
#     14554    0.117    0.000    0.469    0.000 algorithms.py:449(_factorize_array)
#     29108    0.045    0.000    0.240    0.000 algorithms.py:48(_ensure_data)
#     14554    0.153    0.000    2.457    0.000 algorithms.py:576(factorize)
#     14554    0.011    0.000    0.011    0.000 base.py:1329(_get_names)
#     14554    0.020    0.000    0.055    0.000 base.py:1332(_set_names)
#     14554    0.056    0.000    0.360    0.000 base.py:1364(set_names)
#     14554    0.017    0.000    0.377    0.000 base.py:1425(rename)
#     14554    0.005    0.000    0.005    0.000 base.py:1569(is_unique)
#     12723    0.014    0.000    0.056    0.000 base.py:1647(_convert_scalar_indexer)
#     14554    0.023    0.000    0.035    0.000 base.py:1935(_engine)
#     14554    0.011    0.000    0.140    0.000 base.py:1938(<lambda>)
#    100047    0.176    0.000    0.365    0.000 base.py:2033(__contains__)
#     58216    0.062    0.000    0.073    0.000 base.py:2067(__getitem__)
#     29108    0.016    0.000    0.038    0.000 base.py:2445(equals)
#     14554    0.032    0.000    1.004    0.000 base.py:247(__getitem__)
# 43662/29108    0.460    0.000    1.983    0.000 base.py:255(__new__)
#     58216    0.036    0.000    0.097    0.000 base.py:3071(get_loc)
#     12723    0.046    0.000    0.269    0.000 base.py:3090(get_value)
#     12723    0.005    0.000    0.007    0.000 base.py:4117(_maybe_cast_indexer)
#     29108    0.011    0.000    0.013    0.000 base.py:444(<genexpr>)
#     43662    0.097    0.000    0.193    0.000 base.py:473(_simple_new)
#    203756    0.079    0.000    0.106    0.000 base.py:4914(_ensure_index)
#     14554    0.036    0.000    0.140    0.000 base.py:510(_shallow_copy)
#    582160    0.359    0.000    0.783    0.000 base.py:61(is_dtype)
#     29108    0.018    0.000    0.023    0.000 base.py:615(is_)
#     58216    0.027    0.000    0.027    0.000 base.py:635(_reset_identity)
#    378405    0.120    0.000    0.159    0.000 base.py:641(__len__)
#     58216    0.034    0.000    0.072    0.000 base.py:672(values)
#     14554    0.006    0.000    0.027    0.000 base.py:677(_values)
#     29108    0.005    0.000    0.005    0.000 base.py:719(ndim)
#     14554    0.017    0.000    0.129    0.000 base.py:789(_ndarray_values)
#     14554    0.007    0.000    0.009    0.000 base.py:904(_coerce_to_ndarray)
#     14554    0.013    0.000    0.025    0.000 base.py:920(_get_attributes_dict)
#     14554    0.009    0.000    0.012    0.000 base.py:922(<dictcomp>)
#     14554    0.044    0.000    0.100    0.000 cast.py:1207(construct_1d_object_array_from_listlike)
#     29108    0.019    0.000    0.042    0.000 cast.py:1232(construct_1d_ndarray_preserving_na)
#     14554    0.124    0.000    0.358    0.000 cast.py:257(maybe_promote)
#     29108    0.070    0.000    0.500    0.000 cast.py:74(maybe_downcast_to_dtype)
#    116432    0.118    0.000    0.118    0.000 cast.py:853(maybe_castable)
#     14554    0.025    0.000    0.133    0.000 cast.py:867(maybe_infer_to_datetimelike)
#     29108    0.101    0.000    0.392    0.000 cast.py:971(maybe_cast_to_datetime)
#     72770    0.047    0.000    0.323    0.000 common.py:1043(is_datetime64_any_dtype)
#     29108    0.022    0.000    0.041    0.000 common.py:1170(is_datetime_or_timedelta_dtype)
#    218310    0.076    0.000    0.422    0.000 common.py:122(is_sparse)
#     14554    0.026    0.000    0.190    0.000 common.py:123(_default_index)
#     29108    0.029    0.000    0.178    0.000 common.py:1405(needs_i8_conversion)
#     58216    0.077    0.000    0.125    0.000 common.py:1446(is_numeric_dtype)
#     43662    0.028    0.000    0.081    0.000 common.py:1527(is_float_dtype)
#     14554    0.006    0.000    0.006    0.000 common.py:154(_all_none)
#    145540    0.092    0.000    0.548    0.000 common.py:1578(is_bool_dtype)
#     29108    0.028    0.000    0.221    0.000 common.py:1629(is_extension_type)
#     87324    0.122    0.000    0.404    0.000 common.py:1688(is_extension_array_dtype)
#     29108    0.016    0.000    0.064    0.000 common.py:1717(is_complex_dtype)
#     29108    0.020    0.000    0.025    0.000 common.py:1784(_get_dtype)
# 756808/742254    0.674    0.000    1.247    0.000 common.py:1835(_get_dtype_type)
#     14554    0.020    0.000    0.023    0.000 common.py:191(_dict_keys_to_ordered_list)
#     29108    0.016    0.000    0.081    0.000 common.py:195(is_categorical)
#     29108    0.174    0.000    0.269    0.000 common.py:1965(pandas_dtype)
#    116432    0.057    0.000    0.266    0.000 common.py:227(is_datetimetz)
#     29108    0.087    0.000    0.288    0.000 common.py:301(_asarray_tuplesafe)
#    145540    0.108    0.000    0.454    0.000 common.py:332(is_datetime64_dtype)
#    291080    0.126    0.000    0.491    0.000 common.py:369(is_datetime64tz_dtype)
#     54554    0.019    0.000    0.026    0.000 common.py:395(_apply_if_callable)
#    130986    0.076    0.000    0.334    0.000 common.py:407(is_timedelta64_dtype)
#     72770    0.037    0.000    0.176    0.000 common.py:444(is_period_dtype)
#    116432    0.042    0.000    0.262    0.000 common.py:477(is_interval_dtype)
#    232864    0.098    0.000    0.375    0.000 common.py:513(is_categorical_dtype)
#     14554    0.011    0.000    0.036    0.000 common.py:692(is_dtype_equal)
#     87324    0.054    0.000    0.181    0.000 common.py:811(is_integer_dtype)
#     58216    0.052    0.000    0.122    0.000 common.py:858(is_signed_integer_dtype)
#     72770    0.025    0.000    0.061    0.000 common.py:89(is_object_dtype)
#     14554    0.008    0.000    0.015    0.000 common.py:907(is_unsigned_integer_dtype)
#     29108    0.018    0.000    0.082    0.000 concat.py:105(_get_sliced_frame_result_type)
#     14554    0.061    0.000    0.183    0.000 core_functions.py:303(shift_to_bin_centers)
#     24554    0.163    0.000    0.163    0.000 core_functions.py:62(in_range)
#     14554    0.013    0.000    0.033    0.000 core_functions.py:79(value_from_measurement)
#     14554    0.007    0.000    0.007    0.000 core_functions.py:80(<listcomp>)
#     14554    0.009    0.000    0.030    0.000 core_functions.py:83(uncertainty_from_measurement)
#     14554    0.004    0.000    0.004    0.000 core_functions.py:84(<listcomp>)
#     43662    0.029    0.000    0.029    0.000 dtypes.py:266(construct_from_string)
#     43662    0.060    0.000    0.085    0.000 dtypes.py:401(__new__)
#     43662    0.064    0.000    0.148    0.000 dtypes.py:459(construct_from_string)
#     72770    0.087    0.000    0.139    0.000 dtypes.py:584(is_dtype)
#     14554    0.018    0.000    0.059    0.000 dtypes.py:675(construct_from_string)
#     72770    0.091    0.000    0.220    0.000 dtypes.py:707(is_dtype)
#     29108    0.018    0.000    0.018    0.000 expressions.py:160(_has_bool_dtype)
#     29108    0.022    0.000    0.039    0.000 expressions.py:170(_bool_arith_check)
#     29108    0.034    0.000    0.988    0.000 expressions.py:189(evaluate)
#     29108    0.085    0.000    0.464    0.000 expressions.py:60(_evaluate_standard)
#     29108    0.049    0.000    0.416    0.000 expressions.py:68(_can_use_numexpr)
#     29108    0.035    0.000    0.915    0.000 expressions.py:93(_evaluate_numexpr)
#      7277    0.043    0.000    0.253    0.000 fit_functions.py:25(chi2f)
#      7277    0.062    0.000    0.073    0.000 fit_functions.py:39(<listcomp>)
#     14554    0.359    0.000   24.388    0.002 fit_functions_ic.py:176(profileX)
#      7277    0.369    0.000   26.897    0.004 fit_lt_functions.py:209(fit_lifetime_unbined)
#      7277    0.044    0.000    0.044    0.000 fit_lt_functions.py:274(<lambda>)
#      7277    0.064    0.000   27.390    0.004 fit_lt_functions.py:303(time_fcs)
#      7277    0.114    0.000    0.121    0.000 fit_lt_functions.py:355(<listcomp>)
#      7277    0.010    0.000    0.019    0.000 fit_lt_functions.py:370(<listcomp>)
#      7277    0.012    0.000    0.029    0.000 fit_lt_functions.py:371(<listcomp>)
#      7277    0.008    0.000   27.008    0.004 fit_lt_functions.py:376(<listcomp>)
#     10000    0.126    0.000    0.305    0.000 fit_lt_functions.py:393(get_time_series)
#     10000    0.002    0.000    0.002    0.000 fit_lt_functions.py:426(<listcomp>)
#     10000    0.006    0.000    0.006    0.000 fit_lt_functions.py:429(<listcomp>)
#     10000    0.012    0.000    0.093    0.000 fit_lt_functions.py:435(<listcomp>)
#      7277    0.026    0.000    0.054    0.000 fit_lt_functions.py:440(pars_from_fcs)
#         1    0.000    0.000   28.264   28.264 fit_lt_functions.py:489(fit_map_xy)
#       100    0.016    0.000   28.263    0.283 fit_lt_functions.py:550(<listcomp>)
#     10000    0.133    0.000   28.248    0.003 fit_lt_functions.py:556(fit_fcs_in_xy_bin)
#      7277    0.069    0.000   27.000    0.004 fit_lt_functions.py:57(fit_lifetime)
#     41831    0.098    0.000    1.592    0.000 frame.py:2664(__getitem__)
#     41831    0.050    0.000    1.425    0.000 frame.py:2690(_getitem_column)
#     29108    0.052    0.000    0.590    0.000 frame.py:3093(_box_item_values)
#     29108    0.056    0.000    0.460    0.000 frame.py:3100(_box_col_values)
#     14554    0.046    0.000    5.286    0.000 frame.py:334(__init__)
#     14554    0.051    0.000    5.206    0.000 frame.py:426(_init_dict)
#     14554    0.009    0.000    0.009    0.000 frame.py:457(<listcomp>)
#     14554    0.008    0.000    0.008    0.000 frame.py:538(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:555(shape)
#     14554    0.037    0.000    3.695    0.000 frame.py:7349(_arrays_to_mgr)
#     14554    0.113    0.000    0.401    0.000 frame.py:7367(extract_index)
#     14554    0.061    0.000    0.642    0.000 frame.py:7644(_homogenize)
#      7277    0.011    0.000    0.066    0.000 fromnumeric.py:1821(sum)
#     58216    0.068    0.000    0.761    0.000 fromnumeric.py:2478(prod)
#     65493    0.196    0.000    0.746    0.000 fromnumeric.py:64(_wrapreduction)
#     43662    0.060    0.000    0.070    0.000 function.py:326(validate_groupby_func)
#     29108    0.187    0.000    0.223    0.000 function_base.py:1079(diff)
#     14554    0.011    0.000    0.014    0.000 function_base.py:13(_index_deprecate)
#     14554    0.257    0.000    0.411    0.000 function_base.py:25(linspace)
#    130986    0.181    0.000    0.181    0.000 generic.py:124(__init__)
#     14554    0.067    0.000    0.133    0.000 generic.py:1264(_check_label_or_level_ambiguity)
#     14554    0.007    0.000    0.007    0.000 generic.py:1294(<listcomp>)
#     43662    0.033    0.000    0.105    0.000 generic.py:1520(__contains__)
#     14554    0.011    0.000    0.193    0.000 generic.py:164(_validate_dtype)
#     41831    0.087    0.000    1.370    0.000 generic.py:2484(_get_item_cache)
#     29108    0.027    0.000    0.070    0.000 generic.py:2498(_set_as_cached)
#     58216    0.060    0.000    0.080    0.000 generic.py:364(_get_axis_number)
#     14554    0.015    0.000    0.020    0.000 generic.py:377(_get_axis_name)
#     14554    0.010    0.000    0.039    0.000 generic.py:390(_get_axis)
#     14554    0.021    0.000    0.049    0.000 generic.py:4345(__finalize__)
#    145540    0.132    0.000    0.132    0.000 generic.py:4362(__getattr__)
#    247418    0.375    0.000    0.792    0.000 generic.py:4378(__setattr__)
#     43662    0.018    0.000    0.032    0.000 generic.py:438(_info_axis)
#     29108    0.034    0.000    0.107    0.000 generic.py:4423(_protect_consolidate)
#     29108    0.020    0.000    0.127    0.000 generic.py:4433(_consolidate_inplace)
#     29108    0.026    0.000    0.067    0.000 generic.py:4436(f)
#     14554    0.007    0.000    0.014    0.000 generic.py:458(ndim)
#     14554    0.068    0.000    2.432    0.000 generic.py:6592(groupby)
#   1191597    0.377    0.000    0.527    0.000 generic.py:7(_check)
#      7277    0.011    0.000    0.013    0.000 getlimits.py:376(__new__)
#     29108    0.184    0.000    8.335    0.000 groupby.py:1040(_cython_agg_general)
#     14554    0.025    0.000    6.161    0.000 groupby.py:1296(mean)
#     14554    0.242    0.000    3.225    0.000 groupby.py:1335(std)
#     14554    0.019    0.000    2.258    0.000 groupby.py:1353(var)
#     14554    0.032    0.000    1.476    0.000 groupby.py:1390(size)
#     14554    0.030    0.000    2.315    0.000 groupby.py:2143(groupby)
#     14554    0.015    0.000    0.016    0.000 groupby.py:2196(__init__)
#     14554    0.012    0.000    0.019    0.000 groupby.py:2299(names)
#     14554    0.007    0.000    0.007    0.000 groupby.py:2301(<listcomp>)
#     14554    0.129    0.000    1.401    0.000 groupby.py:2303(size)
#     14554    0.016    0.000    0.124    0.000 groupby.py:2333(group_info)
#     14554    0.034    0.000    0.103    0.000 groupby.py:2350(_get_compressed_labels)
#     14554    0.010    0.000    0.014    0.000 groupby.py:2351(<listcomp>)
#     14554    0.014    0.000    3.584    0.000 groupby.py:2360(ngroups)
#     14554    0.044    0.000    3.558    0.000 groupby.py:2371(result_index)
#     29108    0.048    0.000    0.147    0.000 groupby.py:2452(_get_cython_function)
#     29108    0.050    0.000    0.096    0.000 groupby.py:2456(get_func)
#     29108    0.383    0.000    5.923    0.000 groupby.py:2493(_cython_operation)
#     29108    0.052    0.000    5.975    0.000 groupby.py:2625(aggregate)
#     29108    0.025    0.000    0.583    0.000 groupby.py:2632(_aggregate)
#     14554    0.074    0.000    0.303    0.000 groupby.py:2939(__init__)
#     29108    0.008    0.000    0.008    0.000 groupby.py:3067(labels)
#     14554    0.009    0.000    3.116    0.000 groupby.py:3073(result_index)
#     29108    0.016    0.000    3.110    0.000 groupby.py:3089(group_index)
#     14554    0.047    0.000    3.094    0.000 groupby.py:3095(_make_labels)
#     14554    0.219    0.000    2.057    0.000 groupby.py:3114(_get_grouper)
#     29108    0.012    0.000    0.015    0.000 groupby.py:3228(<genexpr>)
#     29108    0.007    0.000    0.008    0.000 groupby.py:3229(<genexpr>)
#     29108    0.012    0.000    0.016    0.000 groupby.py:3230(<genexpr>)
#     29108    0.018    0.000    0.305    0.000 groupby.py:3235(<genexpr>)
#     14554    0.006    0.000    0.016    0.000 groupby.py:3258(is_in_axis)
#     14554    0.028    0.000    0.030    0.000 groupby.py:3268(is_in_obj)
#     14554    0.008    0.000    0.010    0.000 groupby.py:3327(_is_label_like)
#     14554    0.028    0.000    0.116    0.000 groupby.py:3332(_convert_grouper)
#     87324    0.025    0.000    0.025    0.000 groupby.py:3417(_selection_name)
#     29108    0.062    0.000    1.204    0.000 groupby.py:3567(_wrap_output)
#     29108    0.033    0.000    1.237    0.000 groupby.py:3579(_wrap_aggregated_output)
#     14554    0.033    0.000    0.917    0.000 groupby.py:4660(_gotitem)
#     29108    0.153    0.000    2.457    0.000 groupby.py:567(__init__)
#     14554    0.011    0.000    0.013    0.000 groupby.py:694(_selected_obj)
#     29108    0.033    0.000    1.077    0.000 groupby.py:756(__getattr__)
#     58216    0.050    0.000    0.087    0.000 groupby.py:943(_iterate_slices)
#     29108    0.060    0.000    0.683    0.000 groupby.py:981(_try_cast)
#     14554    0.254    0.000   24.642    0.002 histo_functions.py:23(profile1d)
#     14554    0.008    0.000    0.014    0.000 inference.py:119(is_iterator)
#    203756    0.108    0.000    0.400    0.000 inference.py:251(is_list_like)
#     14554    0.009    0.000    0.046    0.000 inference.py:287(is_array_like)
#    145540    0.061    0.000    0.084    0.000 inference.py:415(is_hashable)
#    145540    0.288    0.000    0.974    0.000 internals.py:116(__init__)
#    145540    0.055    0.000    0.055    0.000 internals.py:127(_check_ndim)
#    101878    0.017    0.000    0.017    0.000 internals.py:199(external_values)
#     41831    0.008    0.000    0.008    0.000 internals.py:203(internal_values)
#     27277    0.014    0.000    0.032    0.000 internals.py:222(to_dense)
#    203756    0.036    0.000    0.036    0.000 internals.py:233(mgr_locs)
#    145540    0.209    0.000    0.490    0.000 internals.py:237(mgr_locs)
#     29108    0.022    0.000    0.169    0.000 internals.py:269(make_block_same_class)
#    145540    0.202    0.000    0.623    0.000 internals.py:3148(get_block_type)
#    145540    0.217    0.000    1.670    0.000 internals.py:3191(make_block)
#     14554    0.055    0.000    0.908    0.000 internals.py:3265(__init__)
#     14554    0.014    0.000    0.028    0.000 internals.py:3266(<listcomp>)
#     43662    0.058    0.000    0.190    0.000 internals.py:3307(shape)
#    130986    0.030    0.000    0.132    0.000 internals.py:3309(<genexpr>)
#     43662    0.015    0.000    0.018    0.000 internals.py:3311(ndim)
#     14554    0.193    0.000    0.507    0.000 internals.py:3363(_rebuild_blknos_and_blklocs)
#     72770    0.016    0.000    0.016    0.000 internals.py:3384(_get_items)
#     29108    0.008    0.000    0.008    0.000 internals.py:348(shape)
#     14554    0.049    0.000    0.187    0.000 internals.py:3488(_verify_integrity)
#     43662    0.017    0.000    0.028    0.000 internals.py:3490(<genexpr>)
#    231033    0.055    0.000    0.055    0.000 internals.py:352(dtype)
#     29108    0.020    0.000    0.072    0.000 internals.py:356(ftype)
#     29108    0.021    0.000    0.021    0.000 internals.py:372(iget)
#     29108    0.008    0.000    0.008    0.000 internals.py:3776(is_consolidated)
#     14554    0.026    0.000    0.119    0.000 internals.py:3784(_consolidate_check)
#     14554    0.018    0.000    0.090    0.000 internals.py:3785(<listcomp>)
#     29108    0.013    0.000    0.019    0.000 internals.py:4085(consolidate)
#     14554    0.006    0.000    0.011    0.000 internals.py:4101(_consolidate_inplace)
#     29108    0.068    0.000    0.599    0.000 internals.py:4108(get)
#     29108    0.121    0.000    0.411    0.000 internals.py:4137(iget)
#    116432    0.254    0.000    1.198    0.000 internals.py:4639(__init__)
#    372911    0.081    0.000    0.081    0.000 internals.py:4684(_block)
#    201925    0.123    0.000    0.218    0.000 internals.py:4718(dtype)
#    101878    0.064    0.000    0.101    0.000 internals.py:4742(external_values)
#     41831    0.029    0.000    0.045    0.000 internals.py:4745(internal_values)
#     27277    0.028    0.000    0.079    0.000 internals.py:4752(get_values)
#     14554    0.002    0.000    0.002    0.000 internals.py:4768(is_consolidated)
#     14554    0.049    0.000    2.603    0.000 internals.py:4869(create_block_manager_from_arrays)
#     14554    0.257    0.000    1.635    0.000 internals.py:4880(form_blocks)
#     29108    0.100    0.000    1.112    0.000 internals.py:4986(_multi_blockify)
#     29108    0.009    0.000    0.009    0.000 internals.py:4990(<lambda>)
#     29108    0.135    0.000    0.297    0.000 internals.py:5017(_stack_arrays)
#     29108    0.023    0.000    0.066    0.000 internals.py:5020(_asarray_compat)
#     29108    0.015    0.000    0.041    0.000 internals.py:5026(_shape_compat)
#     14554    0.011    0.000    0.011    0.000 linalg.py:103(get_linalg_error_extobj)
#     21831    0.019    0.000    0.039    0.000 linalg.py:108(_makearray)
#     36385    0.011    0.000    0.015    0.000 linalg.py:113(isComplexType)
#     29108    0.011    0.000    0.015    0.000 linalg.py:126(_realType)
#      7277    0.001    0.000    0.001    0.000 linalg.py:132(_linalgRealType)
#     14554    0.033    0.000    0.059    0.000 linalg.py:141(_commonType)
#      7277    0.005    0.000    0.005    0.000 linalg.py:194(_assertRank2)
#      7277    0.005    0.000    0.005    0.000 linalg.py:200(_assertRankAtLeast2)
#      7277    0.468    0.000    0.603    0.000 linalg.py:2028(lstsq)
#      7277    0.005    0.000    0.005    0.000 linalg.py:211(_assertNdSquareness)
#     14554    0.004    0.000    0.004    0.000 linalg.py:222(_isEmpty2d)
#      7277    0.006    0.000    0.010    0.000 linalg.py:226(_assertNoEmpty2d)
#      7277    0.075    0.000    0.138    0.000 linalg.py:468(inv)
#     58216    0.045    0.000    0.078    0.000 missing.py:112(_isna_new)
#     58216    0.025    0.000    0.103    0.000 missing.py:32(isna)
#     29108    0.035    0.000    0.185    0.000 missing.py:358(_isna_compat)
#     29108    0.024    0.000    0.236    0.000 missing.py:485(_maybe_fill)
#     29108    0.012    0.000    0.060    0.000 missing.py:600(fill_zeros)
#      7277    0.074    0.000    0.088    0.000 numeric.py:1048(outer)
#    116432    0.017    0.000    0.017    0.000 numeric.py:110(is_all_dates)
#     14554    0.011    0.000    0.064    0.000 numeric.py:156(ones)
#     12723    0.025    0.000    0.088    0.000 numeric.py:179(_convert_scalar_indexer)
#     14554    0.008    0.000    0.011    0.000 numeric.py:1927(isscalar)
#    116432    0.182    0.000    0.434    0.000 numeric.py:2491(seterr)
#    116432    0.155    0.000    0.170    0.000 numeric.py:2592(geterr)
#     58216    0.043    0.000    0.058    0.000 numeric.py:2887(__init__)
#     58216    0.050    0.000    0.313    0.000 numeric.py:2891(__enter__)
#     58216    0.045    0.000    0.215    0.000 numeric.py:2896(__exit__)
#     14554    0.035    0.000    0.152    0.000 numeric.py:35(__new__)
#      7277    0.004    0.000    0.008    0.000 numeric.py:371(count_nonzero)
#    145540    0.051    0.000    0.184    0.000 numeric.py:433(asarray)
#     58216    0.021    0.000    0.075    0.000 numeric.py:504(asanyarray)
#     29108    0.135    0.000    0.260    0.000 numeric.py:630(require)
#     14554    0.029    0.000    0.169    0.000 numeric.py:64(_shallow_copy)
#     58216    0.029    0.000    0.035    0.000 numeric.py:701(<genexpr>)
#     58216    0.063    0.000    0.278    0.000 numeric.py:94(zeros_like)
#     29108    0.094    0.000    1.141    0.000 ops.py:1008(na_op)
#     29108    0.085    0.000    1.543    0.000 ops.py:1030(safe_na_op)
#     29108    0.141    0.000    3.546    0.000 ops.py:1040(wrapper)
#     29108    0.024    0.000    0.086    0.000 ops.py:50(get_op_result_name)
#     14554    0.017    0.000    0.037    0.000 ops.py:73(_maybe_match_name)
#     29108    0.024    0.000    0.067    0.000 ops.py:953(_align_method_SERIES)
#     29108    0.053    0.000    1.176    0.000 ops.py:974(_construct_result)
#      7277    0.277    0.000    1.367    0.000 polynomial.py:393(polyfit)
#     14554    0.045    0.000    0.073    0.000 range.py:131(_simple_new)
#     14554    0.003    0.000    0.003    0.000 range.py:158(_validate_dtype)
#     14554    0.020    0.000    0.061    0.000 range.py:315(equals)
#    114602    0.088    0.000    0.137    0.000 range.py:481(__len__)
#     14554    0.040    0.000    0.148    0.000 range.py:68(__new__)
#     29108    0.020    0.000    0.025    0.000 range.py:84(_ensure_int)
#    116432    0.595    0.000    4.226    0.000 series.py:166(__init__)
#     43662    0.008    0.000    0.008    0.000 series.py:349(_constructor)
#    116432    0.133    0.000    0.193    0.000 series.py:365(_set_axis)
#    116432    0.043    0.000    0.043    0.000 series.py:391(_set_subtyp)
#    276526    0.167    0.000    0.277    0.000 series.py:401(name)
#    116432    0.353    0.000    1.568    0.000 series.py:4019(_sanitize_array)
#    116432    0.115    0.000    0.904    0.000 series.py:4036(_try_cast)
#    174648    0.107    0.000    0.175    0.000 series.py:405(name)
#    201925    0.098    0.000    0.316    0.000 series.py:412(dtype)
#    101878    0.045    0.000    0.146    0.000 series.py:432(values)
#     41831    0.021    0.000    0.066    0.000 series.py:465(_values)
#     27277    0.013    0.000    0.092    0.000 series.py:476(get_values)
#     14554    0.008    0.000    0.062    0.000 series.py:637(__array__)
#     14554    0.033    0.000    0.574    0.000 series.py:643(__array_wrap__)
#     14554    0.013    0.000    0.036    0.000 series.py:650(__array_prepare__)
#     12723    0.026    0.000    0.302    0.000 series.py:764(__getitem__)
#      7277    0.061    0.000    0.127    0.000 twodim_base.py:443(vander)
#     72770    0.026    0.000    0.026    0.000 {built-in method __new__ of type object at 0x105bce6a8}
#    203756    0.086    0.000    0.086    0.000 {built-in method _abc._abc_instancecheck}
#     14554    0.003    0.000    0.003    0.000 {built-in method _operator.index}
#     14554    0.078    0.000    0.078    0.000 {built-in method _operator.pow}
#     14554    0.032    0.000    0.032    0.000 {built-in method _operator.truediv}
#      2723    0.006    0.000    0.006    0.000 {built-in method _warnings.warn}
#    108797    0.011    0.000    0.011    0.000 {built-in method builtins.abs}
#     29108    0.019    0.000    0.333    0.000 {built-in method builtins.all}
#     43662    0.025    0.000    0.066    0.000 {built-in method builtins.any}
#     69108    0.009    0.000    0.009    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   28.283   28.283 {built-in method builtins.exec}
#   2243100    0.420    0.000    0.543    0.000 {built-in method builtins.getattr}
#    640376    0.305    0.000    0.309    0.000 {built-in method builtins.hasattr}
#    245587    0.037    0.000    0.037    0.000 {built-in method builtins.hash}
#     14554    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#   8472212    1.409    0.000    2.087    0.000 {built-in method builtins.isinstance}
#   1455400    0.178    0.000    0.178    0.000 {built-in method builtins.issubclass}
#     58216    0.016    0.000    0.016    0.000 {built-in method builtins.iter}
# 2508692/2130287    0.470    0.000    0.727    0.000 {built-in method builtins.len}
#    114602    0.048    0.000    0.048    0.000 {built-in method builtins.max}
#     14554    0.012    0.000    0.040    0.000 {built-in method builtins.sum}
#     72770    0.122    0.000    0.122    0.000 {built-in method numpy.core.multiarray.arange}
#    379296    0.417    0.000    0.417    0.000 {built-in method numpy.core.multiarray.array}
#     14554    0.031    0.000    0.031    0.000 {built-in method numpy.core.multiarray.bincount}
#     72770    0.091    0.000    0.091    0.000 {built-in method numpy.core.multiarray.copyto}
#      7277    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.count_nonzero}
#     14554    0.093    0.000    0.093    0.000 {built-in method numpy.core.multiarray.digitize}
#      7277    0.037    0.000    0.037    0.000 {built-in method numpy.core.multiarray.dot}
#     58216    0.083    0.000    0.083    0.000 {built-in method numpy.core.multiarray.empty_like}
#    138263    0.280    0.000    0.280    0.000 {built-in method numpy.core.multiarray.empty}
#     29108    0.013    0.000    0.013    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#      7277    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.promote_types}
#     14554    0.030    0.000    0.030    0.000 {built-in method numpy.core.multiarray.result_type}
#     90047    0.123    0.000    0.123    0.000 {built-in method numpy.core.multiarray.zeros}
#    232864    0.040    0.000    0.040    0.000 {built-in method numpy.core.umath.geterrobj}
#    116432    0.057    0.000    0.057    0.000 {built-in method numpy.core.umath.seterrobj}
#     29108    0.008    0.000    0.008    0.000 {built-in method pandas._libs.algos.ensure_float64}
#     58216    0.014    0.000    0.014    0.000 {built-in method pandas._libs.algos.ensure_int64}
#     29108    0.006    0.000    0.006    0.000 {built-in method pandas._libs.algos.ensure_platform_int}
#     14554    0.002    0.000    0.002    0.000 {built-in method pandas._libs.lib.is_bool}
#     40000    0.007    0.000    0.007    0.000 {built-in method pandas._libs.lib.is_float}
#     87324    0.013    0.000    0.013    0.000 {built-in method pandas._libs.lib.is_integer}
#    231033    0.136    0.000    0.136    0.000 {built-in method pandas._libs.lib.is_scalar}
#     58216    0.020    0.000    0.020    0.000 {built-in method pandas._libs.missing.checknull}
#     21831    0.004    0.000    0.004    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      7277    0.046    0.000    0.046    0.000 {method 'accumulate' of 'numpy.ufunc' objects}
#     14554    0.012    0.000    0.090    0.000 {method 'any' of 'numpy.ndarray' objects}
#    177371    0.022    0.000    0.022    0.000 {method 'append' of 'list' objects}
#     29108    0.051    0.000    0.051    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     72770    0.098    0.000    0.098    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     29108    0.005    0.000    0.005    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     29108    0.005    0.000    0.005    0.000 {method 'extend' of 'list' objects}
#     60939    0.045    0.000    0.045    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     43662    0.084    0.000    0.084    0.000 {method 'format' of 'str' objects}
#    209202    0.044    0.000    0.044    0.000 {method 'get' of 'dict' objects}
#     14554    0.118    0.000    0.154    0.000 {method 'get_labels' of 'pandas._libs.hashtable.Int64HashTable' objects}
#     58216    0.061    0.000    0.061    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#     12723    0.025    0.000    0.025    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#    123709    0.022    0.000    0.022    0.000 {method 'items' of 'dict' objects}
#     14554    0.003    0.000    0.003    0.000 {method 'keys' of 'dict' objects}
#     14554    0.003    0.000    0.003    0.000 {method 'lower' of 'str' objects}
#    101878    0.024    0.000    0.024    0.000 {method 'pop' of 'dict' objects}
#     14554    0.006    0.000    0.006    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     87324    0.632    0.000    0.632    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     72770    0.024    0.000    0.024    0.000 {method 'rpartition' of 'str' objects}
#     43662    0.020    0.000    0.020    0.000 {method 'search' of 're.Pattern' objects}
#      7277    0.013    0.000    0.013    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#    130986    0.031    0.000    0.031    0.000 {method 'startswith' of 'str' objects}
#      7277    0.008    0.000    0.072    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     14554    0.019    0.000    0.019    0.000 {method 'take' of 'numpy.ndarray' objects}
#     14554    0.047    0.000    0.047    0.000 {method 'to_array' of 'pandas._libs.hashtable.Int64Vector' objects}
#     14554    0.005    0.000    0.005    0.000 {method 'update' of 'dict' objects}
#     29108    0.006    0.000    0.006    0.000 {method 'upper' of 'str' objects}
#     85493    0.056    0.000    0.056    0.000 {method 'view' of 'numpy.ndarray' objects}
#     14554    0.080    0.000    0.080    0.000 {pandas._libs.algos.take_1d_int64_int64}
#     14554    0.125    0.000    0.266    0.000 {pandas._libs.groupby.group_mean_float64}
#     14554    0.156    0.000    0.293    0.000 {pandas._libs.groupby.group_var_float64}
#     14554    0.079    0.000    0.079    0.000 {pandas._libs.lib.infer_dtype}
#     25446    0.019    0.000    0.056    0.000 {pandas._libs.lib.values_from_object}

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cProfile.run("fit_map_xy_df(KXY2, nXY, 1, DT, krNbins.Z, krNbins.S2e, z_range, e_range, 'S2e', FitType.unbined, 100)")
# Out:
#          45102635 function calls (44615075 primitive calls) in 34.119 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    473005    0.247    0.000    0.588    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#     87324    0.062    0.000    0.092    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.019    0.019   34.145   34.145 <string>:1(<module>)
#     10000    0.008    0.000    0.008    0.000 <string>:1(__init__)
#     14554    0.006    0.000    0.011    0.000 <string>:1(__new__)
#     72770    0.032    0.000    0.051    0.000 __init__.py:1361(debug)
#     72770    0.019    0.000    0.019    0.000 __init__.py:1619(isEnabledFor)
#     72770    0.079    0.000    0.136    0.000 __init__.py:1996(debug)
#     65493    0.047    0.000    0.077    0.000 __init__.py:205(iteritems)
#     14554    0.031    0.000    2.524    0.000 _decorators.py:136(wrapper)
#      7277    0.004    0.000    0.065    0.000 _methods.py:34(_sum)
#     65493    0.028    0.000    0.256    0.000 _methods.py:42(_any)
#      7276    0.003    0.000    0.028    0.000 _methods.py:45(_all)
#     29108    0.025    0.000    0.025    0.000 _validators.py:114(_check_for_invalid_keys)
#     29108    0.034    0.000    0.074    0.000 _validators.py:130(validate_kwargs)
#     29108    0.010    0.000    0.010    0.000 _validators.py:32(_check_for_default_values)
#    203756    0.067    0.000    0.155    0.000 abc.py:137(__instancecheck__)
#      7277    0.012    0.000    0.052    0.000 algorithms.py:1297(_take_nd_object)
#     14554    0.042    0.000    0.532    0.000 algorithms.py:141(_reconstruct_data)
#     43662    0.061    0.000    0.084    0.000 algorithms.py:1421(_get_take_nd_function)
#      7277    0.008    0.000    0.062    0.000 algorithms.py:1446(func)
#     43662    0.422    0.000    2.559    0.000 algorithms.py:1548(take_nd)
#     14554    0.008    0.000    0.055    0.000 algorithms.py:172(_ensure_arraylike)
#     14554    0.019    0.000    0.148    0.000 algorithms.py:224(_get_data_algo)
#     14554    0.120    0.000    0.477    0.000 algorithms.py:449(_factorize_array)
#     29108    0.045    0.000    0.242    0.000 algorithms.py:48(_ensure_data)
#     14554    0.155    0.000    2.490    0.000 algorithms.py:576(factorize)
#     14554    0.011    0.000    0.011    0.000 base.py:1329(_get_names)
#     14554    0.021    0.000    0.056    0.000 base.py:1332(_set_names)
#     14554    0.059    0.000    0.370    0.000 base.py:1364(set_names)
#     14554    0.018    0.000    0.388    0.000 base.py:1425(rename)
#     14554    0.005    0.000    0.005    0.000 base.py:1569(is_unique)
#      7277    0.007    0.000    0.017    0.000 base.py:1590(is_object)
#     12723    0.016    0.000    0.059    0.000 base.py:1647(_convert_scalar_indexer)
#     14554    0.025    0.000    0.037    0.000 base.py:1935(_engine)
#     14554    0.012    0.000    0.143    0.000 base.py:1938(<lambda>)
#    139155    0.222    0.000    0.428    0.000 base.py:2033(__contains__)
#     72770    0.079    0.000    0.092    0.000 base.py:2067(__getitem__)
#      7277    0.008    0.000    0.037    0.000 base.py:2101(_can_hold_identifiers_and_holds_name)
#      7277    0.017    0.000    0.410    0.000 base.py:2179(take)
#     36385    0.038    0.000    0.523    0.000 base.py:2445(equals)
#     14554    0.033    0.000    1.024    0.000 base.py:247(__getitem__)
# 50939/36385    0.552    0.000    2.344    0.000 base.py:255(__new__)
#     87324    0.054    0.000    0.147    0.000 base.py:3071(get_loc)
#     12723    0.050    0.000    0.285    0.000 base.py:3090(get_value)
#     12723    0.005    0.000    0.008    0.000 base.py:4117(_maybe_cast_indexer)
#     29108    0.011    0.000    0.013    0.000 base.py:444(<genexpr>)
#     50939    0.116    0.000    0.231    0.000 base.py:473(_simple_new)
#    232864    0.089    0.000    0.121    0.000 base.py:4914(_ensure_index)
#     14554    0.037    0.000    0.142    0.000 base.py:510(_shallow_copy)
#      7277    0.020    0.000    0.356    0.000 base.py:520(_shallow_copy_with_infer)
#    764079    0.474    0.000    1.039    0.000 base.py:61(is_dtype)
#     36385    0.023    0.000    0.029    0.000 base.py:615(is_)
#     65493    0.031    0.000    0.031    0.000 base.py:635(_reset_identity)
#    451175    0.148    0.000    0.195    0.000 base.py:641(__len__)
#      7277    0.003    0.000    0.003    0.000 base.py:662(dtype)
#     80047    0.046    0.000    0.097    0.000 base.py:672(values)
#     14554    0.007    0.000    0.027    0.000 base.py:677(_values)
#     14554    0.006    0.000    0.020    0.000 base.py:711(get_values)
#     29108    0.005    0.000    0.005    0.000 base.py:719(ndim)
#     14554    0.018    0.000    0.132    0.000 base.py:789(_ndarray_values)
#     21831    0.011    0.000    0.014    0.000 base.py:904(_coerce_to_ndarray)
#     21831    0.020    0.000    0.039    0.000 base.py:920(_get_attributes_dict)
#     21831    0.015    0.000    0.019    0.000 base.py:922(<dictcomp>)
#     14554    0.045    0.000    0.102    0.000 cast.py:1207(construct_1d_object_array_from_listlike)
#     29108    0.019    0.000    0.042    0.000 cast.py:1232(construct_1d_ndarray_preserving_na)
#     43662    0.237    0.000    0.982    0.000 cast.py:257(maybe_promote)
#     29108    0.074    0.000    0.513    0.000 cast.py:74(maybe_downcast_to_dtype)
#    116432    0.121    0.000    0.121    0.000 cast.py:853(maybe_castable)
#     14554    0.026    0.000    0.135    0.000 cast.py:867(maybe_infer_to_datetimelike)
#     29108    0.105    0.000    0.400    0.000 cast.py:971(maybe_cast_to_datetime)
#      7277    0.012    0.000    0.021    0.000 common.py:100(is_bool_indexer)
#     80047    0.053    0.000    0.361    0.000 common.py:1043(is_datetime64_any_dtype)
#     50936    0.037    0.000    0.094    0.000 common.py:1170(is_datetime_or_timedelta_dtype)
#    269249    0.096    0.000    0.521    0.000 common.py:122(is_sparse)
#     14554    0.027    0.000    0.198    0.000 common.py:123(_default_index)
#      7276    0.009    0.000    0.109    0.000 common.py:1294(is_datetimelike_v_numeric)
#     50936    0.045    0.000    0.318    0.000 common.py:1405(needs_i8_conversion)
#     58216    0.080    0.000    0.128    0.000 common.py:1446(is_numeric_dtype)
#     50938    0.036    0.000    0.103    0.000 common.py:1527(is_float_dtype)
#     14554    0.006    0.000    0.006    0.000 common.py:154(_all_none)
#    145540    0.093    0.000    0.552    0.000 common.py:1578(is_bool_dtype)
#     29108    0.028    0.000    0.225    0.000 common.py:1629(is_extension_type)
#    174648    0.219    0.000    0.772    0.000 common.py:1688(is_extension_array_dtype)
#     36384    0.020    0.000    0.081    0.000 common.py:1717(is_complex_dtype)
#    116430    0.080    0.000    0.132    0.000 common.py:1784(_get_dtype)
# 829573/815019    0.765    0.000    1.388    0.000 common.py:1835(_get_dtype_type)
#     14554    0.021    0.000    0.025    0.000 common.py:191(_dict_keys_to_ordered_list)
#     29108    0.017    0.000    0.083    0.000 common.py:195(is_categorical)
#     29108    0.177    0.000    0.274    0.000 common.py:1965(pandas_dtype)
#    203756    0.098    0.000    0.589    0.000 common.py:227(is_datetimetz)
#     29108    0.088    0.000    0.294    0.000 common.py:301(_asarray_tuplesafe)
#    152817    0.115    0.000    0.482    0.000 common.py:332(is_datetime64_dtype)
#    407509    0.174    0.000    0.743    0.000 common.py:369(is_datetime64tz_dtype)
#     86385    0.033    0.000    0.044    0.000 common.py:395(_apply_if_callable)
#    138263    0.084    0.000    0.357    0.000 common.py:407(is_timedelta64_dtype)
#     94598    0.047    0.000    0.224    0.000 common.py:444(is_period_dtype)
#    160094    0.064    0.000    0.364    0.000 common.py:477(is_interval_dtype)
#    247418    0.105    0.000    0.395    0.000 common.py:513(is_categorical_dtype)
#     14552    0.010    0.000    0.075    0.000 common.py:546(is_string_dtype)
#     50939    0.037    0.000    0.104    0.000 common.py:692(is_dtype_equal)
#     87324    0.053    0.000    0.181    0.000 common.py:811(is_integer_dtype)
#     65493    0.061    0.000    0.137    0.000 common.py:858(is_signed_integer_dtype)
#     87324    0.036    0.000    0.113    0.000 common.py:89(is_object_dtype)
#     14554    0.008    0.000    0.015    0.000 common.py:907(is_unsigned_integer_dtype)
#     43662    0.026    0.000    0.124    0.000 concat.py:105(_get_sliced_frame_result_type)
#     24554    0.103    0.000    0.299    0.000 core_functions.py:303(shift_to_bin_centers)
#     24554    0.144    0.000    0.144    0.000 core_functions.py:62(in_range)
#     14554    0.013    0.000    0.034    0.000 core_functions.py:79(value_from_measurement)
#     14554    0.007    0.000    0.007    0.000 core_functions.py:80(<listcomp>)
#     14554    0.009    0.000    0.031    0.000 core_functions.py:83(uncertainty_from_measurement)
#     14554    0.004    0.000    0.004    0.000 core_functions.py:84(<listcomp>)
#     43662    0.030    0.000    0.030    0.000 dtypes.py:266(construct_from_string)
#     65493    0.096    0.000    0.147    0.000 dtypes.py:401(__new__)
#     65493    0.096    0.000    0.243    0.000 dtypes.py:459(construct_from_string)
#     94598    0.108    0.000    0.177    0.000 dtypes.py:584(is_dtype)
#     14554    0.019    0.000    0.060    0.000 dtypes.py:675(construct_from_string)
#    109155    0.141    0.000    0.300    0.000 dtypes.py:707(is_dtype)
#     29108    0.018    0.000    0.018    0.000 expressions.py:160(_has_bool_dtype)
#     29108    0.022    0.000    0.041    0.000 expressions.py:170(_bool_arith_check)
#     29108    0.036    0.000    1.011    0.000 expressions.py:189(evaluate)
#     29108    0.086    0.000    0.474    0.000 expressions.py:60(_evaluate_standard)
#     29108    0.050    0.000    0.426    0.000 expressions.py:68(_can_use_numexpr)
#     29108    0.035    0.000    0.935    0.000 expressions.py:93(_evaluate_numexpr)
#      7277    0.044    0.000    0.258    0.000 fit_functions.py:25(chi2f)
#      7277    0.064    0.000    0.075    0.000 fit_functions.py:39(<listcomp>)
#     14554    0.370    0.000   24.864    0.002 fit_functions_ic.py:176(profileX)
#      7277    0.384    0.000   27.501    0.004 fit_lt_functions.py:209(fit_lifetime_unbined)
#      7277    0.045    0.000    0.045    0.000 fit_lt_functions.py:274(<lambda>)
#      7277    0.027    0.000    0.056    0.000 fit_lt_functions.py:440(pars_from_fcs)
#      7277    0.087    0.000   27.645    0.004 fit_lt_functions.py:57(fit_lifetime)
#         1    0.000    0.000   34.126   34.126 fitmap_functions.py:111(fit_map_xy_df)
#     10000    0.148    0.000   34.110    0.003 fitmap_functions.py:166(fit_fcs_in_xy_bin)
#       100    0.016    0.000   34.126    0.341 fitmap_functions.py:203(<listcomp>)
#      7277    0.047    0.000   32.898    0.005 fitmap_functions.py:46(time_fcs_df)
#      7277    0.025    0.000    4.210    0.001 fitmap_functions.py:97(<listcomp>)
#      7277    0.029    0.000   28.507    0.004 fitmap_functions.py:98(<listcomp>)
#     73662    0.205    0.000    6.624    0.000 frame.py:2664(__getitem__)
#     66385    0.077    0.000    2.157    0.000 frame.py:2690(_getitem_column)
#      7277    0.027    0.000    4.112    0.001 frame.py:2707(_getitem_array)
#     43662    0.079    0.000    0.897    0.000 frame.py:3093(_box_item_values)
#     43662    0.084    0.000    0.698    0.000 frame.py:3100(_box_col_values)
#      7277    0.002    0.000    0.002    0.000 frame.py:320(_constructor)
#     21831    0.073    0.000    5.425    0.000 frame.py:334(__init__)
#     14554    0.053    0.000    5.295    0.000 frame.py:426(_init_dict)
#     14554    0.009    0.000    0.009    0.000 frame.py:457(<listcomp>)
#     14554    0.008    0.000    0.008    0.000 frame.py:538(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:555(shape)
#     14554    0.039    0.000    3.746    0.000 frame.py:7349(_arrays_to_mgr)
#     14554    0.114    0.000    0.413    0.000 frame.py:7367(extract_index)
#     14554    0.063    0.000    0.655    0.000 frame.py:7644(_homogenize)
#      7277    0.011    0.000    0.067    0.000 fromnumeric.py:1821(sum)
#     58216    0.070    0.000    0.779    0.000 fromnumeric.py:2478(prod)
#     65493    0.200    0.000    0.763    0.000 fromnumeric.py:64(_wrapreduction)
#     43662    0.062    0.000    0.072    0.000 function.py:326(validate_groupby_func)
#     39108    0.249    0.000    0.298    0.000 function_base.py:1079(diff)
#     24554    0.018    0.000    0.023    0.000 function_base.py:13(_index_deprecate)
#     24554    0.441    0.000    0.696    0.000 function_base.py:25(linspace)
#    152817    0.216    0.000    0.216    0.000 generic.py:124(__init__)
#     14554    0.071    0.000    0.138    0.000 generic.py:1264(_check_label_or_level_ambiguity)
#     14554    0.007    0.000    0.007    0.000 generic.py:1294(<listcomp>)
#     43662    0.035    0.000    0.108    0.000 generic.py:1520(__contains__)
#     14554    0.012    0.000    0.197    0.000 generic.py:164(_validate_dtype)
#      7277    0.008    0.000    0.009    0.000 generic.py:178(_init_mgr)
#     66385    0.132    0.000    2.074    0.000 generic.py:2484(_get_item_cache)
#     43662    0.040    0.000    0.106    0.000 generic.py:2498(_set_as_cached)
#         1    0.000    0.000    0.000    0.000 generic.py:2603(_set_is_copy)
#      7277    0.045    0.000    3.999    0.001 generic.py:2783(_take)
#     65493    0.070    0.000    0.094    0.000 generic.py:364(_get_axis_number)
#     29108    0.027    0.000    0.037    0.000 generic.py:377(_get_axis_name)
#     29108    0.020    0.000    0.070    0.000 generic.py:390(_get_axis)
#      7277    0.006    0.000    0.018    0.000 generic.py:394(_get_block_manager_axis)
#     21831    0.027    0.000    0.057    0.000 generic.py:4345(__finalize__)
# 167371/160094    0.166    0.000    0.610    0.000 generic.py:4362(__getattr__)
#    298358    0.453    0.000    0.934    0.000 generic.py:4378(__setattr__)
#     50939    0.023    0.000    0.039    0.000 generic.py:438(_info_axis)
#     36385    0.044    0.000    0.144    0.000 generic.py:4423(_protect_consolidate)
#     36385    0.026    0.000    0.170    0.000 generic.py:4433(_consolidate_inplace)
#     36385    0.035    0.000    0.093    0.000 generic.py:4436(f)
#     14554    0.008    0.000    0.015    0.000 generic.py:458(ndim)
#     14554    0.070    0.000    2.494    0.000 generic.py:6592(groupby)
#   1657321    0.515    0.000    0.749    0.000 generic.py:7(_check)
#      7277    0.011    0.000    0.013    0.000 getlimits.py:376(__new__)
#     29108    0.189    0.000    8.479    0.000 groupby.py:1040(_cython_agg_general)
#     14554    0.027    0.000    6.267    0.000 groupby.py:1296(mean)
#     14554    0.249    0.000    3.288    0.000 groupby.py:1335(std)
#     14554    0.020    0.000    2.299    0.000 groupby.py:1353(var)
#     14554    0.033    0.000    1.504    0.000 groupby.py:1390(size)
#     14554    0.032    0.000    2.373    0.000 groupby.py:2143(groupby)
#     14554    0.016    0.000    0.017    0.000 groupby.py:2196(__init__)
#     14554    0.013    0.000    0.020    0.000 groupby.py:2299(names)
#     14554    0.007    0.000    0.007    0.000 groupby.py:2301(<listcomp>)
#     14554    0.132    0.000    1.427    0.000 groupby.py:2303(size)
#     14554    0.017    0.000    0.126    0.000 groupby.py:2333(group_info)
#     14554    0.033    0.000    0.104    0.000 groupby.py:2350(_get_compressed_labels)
#     14554    0.010    0.000    0.014    0.000 groupby.py:2351(<listcomp>)
#     14554    0.014    0.000    3.642    0.000 groupby.py:2360(ngroups)
#     14554    0.046    0.000    3.615    0.000 groupby.py:2371(result_index)
#     29108    0.048    0.000    0.148    0.000 groupby.py:2452(_get_cython_function)
#     29108    0.050    0.000    0.097    0.000 groupby.py:2456(get_func)
#     29108    0.386    0.000    6.017    0.000 groupby.py:2493(_cython_operation)
#     29108    0.053    0.000    6.071    0.000 groupby.py:2625(aggregate)
#     29108    0.026    0.000    0.605    0.000 groupby.py:2632(_aggregate)
#     14554    0.075    0.000    0.309    0.000 groupby.py:2939(__init__)
#     29108    0.008    0.000    0.008    0.000 groupby.py:3067(labels)
#     14554    0.009    0.000    3.160    0.000 groupby.py:3073(result_index)
#     29108    0.016    0.000    3.154    0.000 groupby.py:3089(group_index)
#     14554    0.048    0.000    3.137    0.000 groupby.py:3095(_make_labels)
#     14554    0.226    0.000    2.104    0.000 groupby.py:3114(_get_grouper)
#     29108    0.013    0.000    0.016    0.000 groupby.py:3228(<genexpr>)
#     29108    0.007    0.000    0.009    0.000 groupby.py:3229(<genexpr>)
#     29108    0.013    0.000    0.017    0.000 groupby.py:3230(<genexpr>)
#     29108    0.019    0.000    0.314    0.000 groupby.py:3235(<genexpr>)
#     14554    0.007    0.000    0.017    0.000 groupby.py:3258(is_in_axis)
#     14554    0.029    0.000    0.031    0.000 groupby.py:3268(is_in_obj)
#     14554    0.008    0.000    0.010    0.000 groupby.py:3327(_is_label_like)
#     14554    0.029    0.000    0.119    0.000 groupby.py:3332(_convert_grouper)
#     87324    0.025    0.000    0.025    0.000 groupby.py:3417(_selection_name)
#     29108    0.063    0.000    1.222    0.000 groupby.py:3567(_wrap_output)
#     29108    0.034    0.000    1.256    0.000 groupby.py:3579(_wrap_aggregated_output)
#     14554    0.035    0.000    0.934    0.000 groupby.py:4660(_gotitem)
#     29108    0.159    0.000    2.517    0.000 groupby.py:567(__init__)
#     14554    0.011    0.000    0.013    0.000 groupby.py:694(_selected_obj)
#     29108    0.034    0.000    1.099    0.000 groupby.py:756(__getattr__)
#     58216    0.053    0.000    0.090    0.000 groupby.py:943(_iterate_slices)
#     29108    0.062    0.000    0.700    0.000 groupby.py:981(_try_cast)
#     14554    0.260    0.000   25.125    0.002 histo_functions.py:23(profile1d)
#      7277    0.010    0.000    0.012    0.000 indexing.py:2321(convert_to_index_sliceable)
#      7277    0.011    0.000    0.043    0.000 indexing.py:2345(check_bool_indexer)
#      7277    0.057    0.000    0.122    0.000 indexing.py:2441(maybe_convert_indices)
#     14554    0.008    0.000    0.015    0.000 inference.py:119(is_iterator)
#    203756    0.112    0.000    0.412    0.000 inference.py:251(is_list_like)
#     14554    0.009    0.000    0.048    0.000 inference.py:287(is_array_like)
#    160094    0.069    0.000    0.095    0.000 inference.py:415(is_hashable)
#    189202    0.373    0.000    1.140    0.000 internals.py:116(__init__)
#     29108    0.098    0.000    2.062    0.000 internals.py:1237(take_nd)
#    189202    0.072    0.000    0.072    0.000 internals.py:127(_check_ndim)
#    126432    0.022    0.000    0.022    0.000 internals.py:199(external_values)
#     41831    0.008    0.000    0.008    0.000 internals.py:203(internal_values)
#     27277    0.015    0.000    0.033    0.000 internals.py:222(to_dense)
#     29108    0.007    0.000    0.007    0.000 internals.py:229(fill_value)
#    334742    0.057    0.000    0.057    0.000 internals.py:233(mgr_locs)
#    189202    0.239    0.000    0.528    0.000 internals.py:237(mgr_locs)
#     72770    0.055    0.000    0.412    0.000 internals.py:269(make_block_same_class)
#    145540    0.203    0.000    0.627    0.000 internals.py:3148(get_block_type)
#    189202    0.275    0.000    1.897    0.000 internals.py:3191(make_block)
#     21831    0.086    0.000    1.424    0.000 internals.py:3265(__init__)
#     21831    0.021    0.000    0.042    0.000 internals.py:3266(<listcomp>)
#     72770    0.103    0.000    0.304    0.000 internals.py:3307(shape)
#    218310    0.052    0.000    0.201    0.000 internals.py:3309(<genexpr>)
#     80047    0.026    0.000    0.034    0.000 internals.py:3311(ndim)
#     21831    0.311    0.000    0.774    0.000 internals.py:3363(_rebuild_blknos_and_blklocs)
#    109155    0.024    0.000    0.024    0.000 internals.py:3384(_get_items)
#     58216    0.014    0.000    0.014    0.000 internals.py:348(shape)
#     21831    0.080    0.000    0.294    0.000 internals.py:3488(_verify_integrity)
#     80047    0.031    0.000    0.050    0.000 internals.py:3490(<genexpr>)
#    289249    0.066    0.000    0.066    0.000 internals.py:352(dtype)
#     58216    0.037    0.000    0.129    0.000 internals.py:356(ftype)
#     43662    0.032    0.000    0.032    0.000 internals.py:372(iget)
#     50939    0.015    0.000    0.015    0.000 internals.py:3776(is_consolidated)
#     21831    0.042    0.000    0.205    0.000 internals.py:3784(_consolidate_check)
#     21831    0.029    0.000    0.159    0.000 internals.py:3785(<listcomp>)
#     36385    0.018    0.000    0.026    0.000 internals.py:4085(consolidate)
#     29108    0.012    0.000    0.021    0.000 internals.py:4101(_consolidate_inplace)
#     43662    0.101    0.000    0.899    0.000 internals.py:4108(get)
#     43662    0.180    0.000    0.614    0.000 internals.py:4137(iget)
#      7277    0.025    0.000    2.649    0.000 internals.py:4388(reindex_indexer)
#      7277    0.036    0.000    2.105    0.000 internals.py:4423(<listcomp>)
#      7277    0.062    0.000    3.324    0.000 internals.py:4518(take)
#    130986    0.286    0.000    1.258    0.000 internals.py:4639(__init__)
#    397465    0.091    0.000    0.091    0.000 internals.py:4684(_block)
#    201925    0.125    0.000    0.221    0.000 internals.py:4718(dtype)
#    126432    0.084    0.000    0.134    0.000 internals.py:4742(external_values)
#     41831    0.031    0.000    0.049    0.000 internals.py:4745(internal_values)
#     27277    0.030    0.000    0.082    0.000 internals.py:4752(get_values)
#     14554    0.002    0.000    0.002    0.000 internals.py:4768(is_consolidated)
#     14554    0.048    0.000    2.626    0.000 internals.py:4869(create_block_manager_from_arrays)
#     14554    0.259    0.000    1.653    0.000 internals.py:4880(form_blocks)
#     29108    0.103    0.000    1.125    0.000 internals.py:4986(_multi_blockify)
#     29108    0.009    0.000    0.009    0.000 internals.py:4990(<lambda>)
#     29108    0.137    0.000    0.301    0.000 internals.py:5017(_stack_arrays)
#     29108    0.023    0.000    0.066    0.000 internals.py:5020(_asarray_compat)
#     29108    0.015    0.000    0.042    0.000 internals.py:5026(_shape_compat)
#     14554    0.011    0.000    0.011    0.000 linalg.py:103(get_linalg_error_extobj)
#     21831    0.019    0.000    0.040    0.000 linalg.py:108(_makearray)
#     36385    0.011    0.000    0.015    0.000 linalg.py:113(isComplexType)
#     29108    0.011    0.000    0.016    0.000 linalg.py:126(_realType)
#      7277    0.001    0.000    0.001    0.000 linalg.py:132(_linalgRealType)
#     14554    0.034    0.000    0.060    0.000 linalg.py:141(_commonType)
#      7277    0.005    0.000    0.005    0.000 linalg.py:194(_assertRank2)
#      7277    0.005    0.000    0.005    0.000 linalg.py:200(_assertRankAtLeast2)
#      7277    0.501    0.000    0.642    0.000 linalg.py:2028(lstsq)
#      7277    0.005    0.000    0.005    0.000 linalg.py:211(_assertNdSquareness)
#     14554    0.004    0.000    0.004    0.000 linalg.py:222(_isEmpty2d)
#      7277    0.006    0.000    0.010    0.000 linalg.py:226(_assertNoEmpty2d)
#      7277    0.079    0.000    0.143    0.000 linalg.py:468(inv)
#     72770    0.059    0.000    0.101    0.000 missing.py:112(_isna_new)
#     72770    0.032    0.000    0.133    0.000 missing.py:32(isna)
#     29108    0.036    0.000    0.187    0.000 missing.py:358(_isna_compat)
#      7277    0.035    0.000    0.384    0.000 missing.py:376(array_equivalent)
#     29108    0.025    0.000    0.240    0.000 missing.py:485(_maybe_fill)
#     29108    0.012    0.000    0.061    0.000 missing.py:600(fill_zeros)
#      7277    0.086    0.000    0.100    0.000 numeric.py:1048(outer)
#    130986    0.020    0.000    0.020    0.000 numeric.py:110(is_all_dates)
#     14554    0.012    0.000    0.062    0.000 numeric.py:156(ones)
#     12723    0.026    0.000    0.093    0.000 numeric.py:179(_convert_scalar_indexer)
#     24554    0.013    0.000    0.018    0.000 numeric.py:1927(isscalar)
#      7276    0.032    0.000    0.078    0.000 numeric.py:2389(array_equal)
#    116432    0.187    0.000    0.445    0.000 numeric.py:2491(seterr)
#    116432    0.158    0.000    0.174    0.000 numeric.py:2592(geterr)
#     58216    0.045    0.000    0.059    0.000 numeric.py:2887(__init__)
#     58216    0.051    0.000    0.321    0.000 numeric.py:2891(__enter__)
#     58216    0.046    0.000    0.220    0.000 numeric.py:2896(__exit__)
#     21831    0.055    0.000    0.235    0.000 numeric.py:35(__new__)
#    218307    0.077    0.000    0.245    0.000 numeric.py:433(asarray)
#     95493    0.034    0.000    0.143    0.000 numeric.py:504(asanyarray)
#     29108    0.136    0.000    0.264    0.000 numeric.py:630(require)
#     21831    0.044    0.000    0.542    0.000 numeric.py:64(_shallow_copy)
#     58216    0.029    0.000    0.036    0.000 numeric.py:701(<genexpr>)
#     58216    0.064    0.000    0.288    0.000 numeric.py:94(zeros_like)
#     29108    0.098    0.000    1.170    0.000 ops.py:1008(na_op)
#     29108    0.088    0.000    1.584    0.000 ops.py:1030(safe_na_op)
#     29108    0.143    0.000    3.623    0.000 ops.py:1040(wrapper)
#     29108    0.025    0.000    0.089    0.000 ops.py:50(get_op_result_name)
#     14554    0.018    0.000    0.038    0.000 ops.py:73(_maybe_match_name)
#     29108    0.025    0.000    0.069    0.000 ops.py:953(_align_method_SERIES)
#     29108    0.054    0.000    1.196    0.000 ops.py:974(_construct_result)
#      7277    0.297    0.000    1.458    0.000 polynomial.py:393(polyfit)
#     14554    0.049    0.000    0.077    0.000 range.py:131(_simple_new)
#     14554    0.003    0.000    0.003    0.000 range.py:158(_validate_dtype)
#     14554    0.020    0.000    0.062    0.000 range.py:315(equals)
#    114602    0.091    0.000    0.139    0.000 range.py:481(__len__)
#     14554    0.041    0.000    0.155    0.000 range.py:68(__new__)
#     29108    0.021    0.000    0.026    0.000 range.py:84(_ensure_int)
#     10000    0.024    0.000    0.175    0.000 selection_functions.py:107(<listcomp>)
#     10000    0.043    0.000    0.636    0.000 selection_functions.py:74(get_time_series_df)
#    130986    0.633    0.000    4.457    0.000 series.py:166(__init__)
#     43662    0.007    0.000    0.007    0.000 series.py:349(_constructor)
#    130986    0.154    0.000    0.223    0.000 series.py:365(_set_axis)
#    130986    0.050    0.000    0.050    0.000 series.py:391(_set_subtyp)
#    291080    0.192    0.000    0.318    0.000 series.py:401(name)
#    116432    0.356    0.000    1.595    0.000 series.py:4019(_sanitize_array)
#    116432    0.117    0.000    0.923    0.000 series.py:4036(_try_cast)
#    189202    0.121    0.000    0.198    0.000 series.py:405(name)
#    201925    0.098    0.000    0.319    0.000 series.py:412(dtype)
#    126432    0.060    0.000    0.194    0.000 series.py:432(values)
#     41831    0.022    0.000    0.071    0.000 series.py:465(_values)
#     27277    0.014    0.000    0.096    0.000 series.py:476(get_values)
#     14554    0.008    0.000    0.066    0.000 series.py:637(__array__)
#     14554    0.034    0.000    0.583    0.000 series.py:643(__array_wrap__)
#     14554    0.014    0.000    0.039    0.000 series.py:650(__array_prepare__)
#     12723    0.028    0.000    0.320    0.000 series.py:764(__getitem__)
#      7277    0.068    0.000    0.137    0.000 twodim_base.py:443(vander)
#         5    0.000    0.000    0.000    0.000 typing.py:245(inner)
#         6    0.000    0.000    0.000    0.000 typing.py:661(__hash__)
#         3    0.000    0.000    0.000    0.000 typing.py:741(__getitem__)
#     80047    0.029    0.000    0.029    0.000 {built-in method __new__ of type object at 0x105bce6a8}
#    203756    0.088    0.000    0.088    0.000 {built-in method _abc._abc_instancecheck}
#     24554    0.005    0.000    0.005    0.000 {built-in method _operator.index}
#     14554    0.081    0.000    0.081    0.000 {built-in method _operator.pow}
#     14554    0.033    0.000    0.033    0.000 {built-in method _operator.truediv}
#      2723    0.007    0.000    0.007    0.000 {built-in method _warnings.warn}
#    108797    0.011    0.000    0.011    0.000 {built-in method builtins.abs}
#     29108    0.019    0.000    0.343    0.000 {built-in method builtins.all}
#     43662    0.026    0.000    0.067    0.000 {built-in method builtins.any}
#    100939    0.013    0.000    0.013    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   34.145   34.145 {built-in method builtins.exec}
#   2927128    0.542    0.000    0.668    0.000 {built-in method builtins.getattr}
#    887790    0.370    0.000    0.374    0.000 {built-in method builtins.hasattr}
#    299255    0.050    0.000    0.050    0.000 {built-in method builtins.hash}
#     14554    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#  10144031    1.742    0.000    2.645    0.000 {built-in method builtins.isinstance}
#   1659151    0.209    0.000    0.209    0.000 {built-in method builtins.issubclass}
#     65493    0.018    0.000    0.018    0.000 {built-in method builtins.iter}
# 2848925/2397750    0.548    0.000    0.835    0.000 {built-in method builtins.len}
#    114602    0.048    0.000    0.048    0.000 {built-in method builtins.max}
#     21831    0.020    0.000    0.070    0.000 {built-in method builtins.sum}
#    111878    0.173    0.000    0.173    0.000 {built-in method numpy.core.multiarray.arange}
#    489340    0.523    0.000    0.523    0.000 {built-in method numpy.core.multiarray.array}
#     14554    0.032    0.000    0.032    0.000 {built-in method numpy.core.multiarray.bincount}
#     72770    0.096    0.000    0.096    0.000 {built-in method numpy.core.multiarray.copyto}
#     14554    0.094    0.000    0.094    0.000 {built-in method numpy.core.multiarray.digitize}
#      7277    0.042    0.000    0.042    0.000 {built-in method numpy.core.multiarray.dot}
#     58216    0.086    0.000    0.086    0.000 {built-in method numpy.core.multiarray.empty_like}
#    181925    0.342    0.000    0.342    0.000 {built-in method numpy.core.multiarray.empty}
#     39108    0.017    0.000    0.017    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#      7277    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.promote_types}
#     24554    0.046    0.000    0.046    0.000 {built-in method numpy.core.multiarray.result_type}
#     90047    0.127    0.000    0.127    0.000 {built-in method numpy.core.multiarray.zeros}
#    232864    0.041    0.000    0.041    0.000 {built-in method numpy.core.umath.geterrobj}
#    116432    0.058    0.000    0.058    0.000 {built-in method numpy.core.umath.seterrobj}
#     29108    0.009    0.000    0.009    0.000 {built-in method pandas._libs.algos.ensure_float64}
#     94601    0.025    0.000    0.025    0.000 {built-in method pandas._libs.algos.ensure_int64}
#     43662    0.009    0.000    0.009    0.000 {built-in method pandas._libs.algos.ensure_platform_int}
#     14554    0.002    0.000    0.002    0.000 {built-in method pandas._libs.lib.is_bool}
#     69108    0.012    0.000    0.012    0.000 {built-in method pandas._libs.lib.is_float}
#     94601    0.015    0.000    0.015    0.000 {built-in method pandas._libs.lib.is_integer}
#    260141    0.147    0.000    0.147    0.000 {built-in method pandas._libs.lib.is_scalar}
#     72770    0.027    0.000    0.027    0.000 {built-in method pandas._libs.missing.checknull}
#     21831    0.004    0.000    0.004    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      7277    0.048    0.000    0.048    0.000 {method 'accumulate' of 'numpy.ufunc' objects}
#      7276    0.005    0.000    0.034    0.000 {method 'all' of 'numpy.ndarray' objects}
#     65493    0.042    0.000    0.298    0.000 {method 'any' of 'numpy.ndarray' objects}
#    167371    0.022    0.000    0.022    0.000 {method 'append' of 'list' objects}
#     29108    0.053    0.000    0.053    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     82770    0.111    0.000    0.111    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     29108    0.005    0.000    0.005    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     29108    0.005    0.000    0.005    0.000 {method 'extend' of 'list' objects}
#     75493    0.054    0.000    0.054    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     72770    0.121    0.000    0.121    0.000 {method 'format' of 'str' objects}
#    291972    0.071    0.000    0.071    0.000 {method 'get' of 'dict' objects}
#     14554    0.120    0.000    0.157    0.000 {method 'get_labels' of 'pandas._libs.hashtable.Int64HashTable' objects}
#     87324    0.093    0.000    0.093    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#     12723    0.027    0.000    0.027    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#    138263    0.025    0.000    0.025    0.000 {method 'items' of 'dict' objects}
#     14554    0.003    0.000    0.003    0.000 {method 'keys' of 'dict' objects}
#     14554    0.004    0.000    0.004    0.000 {method 'lower' of 'str' objects}
#      7277    0.011    0.000    0.011    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#    101878    0.024    0.000    0.024    0.000 {method 'pop' of 'dict' objects}
#     14554    0.007    0.000    0.007    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    145539    0.826    0.000    0.826    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     87324    0.030    0.000    0.030    0.000 {method 'rpartition' of 'str' objects}
#     65493    0.044    0.000    0.044    0.000 {method 'search' of 're.Pattern' objects}
#      7277    0.017    0.000    0.017    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#    130986    0.032    0.000    0.032    0.000 {method 'startswith' of 'str' objects}
#      7277    0.008    0.000    0.073    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     29108    0.071    0.000    0.071    0.000 {method 'take' of 'numpy.ndarray' objects}
#     14554    0.047    0.000    0.047    0.000 {method 'to_array' of 'pandas._libs.hashtable.Int64Vector' objects}
#     21831    0.007    0.000    0.007    0.000 {method 'update' of 'dict' objects}
#     29108    0.006    0.000    0.006    0.000 {method 'upper' of 'str' objects}
#    107324    0.070    0.000    0.070    0.000 {method 'view' of 'numpy.ndarray' objects}
#     14554    0.081    0.000    0.081    0.000 {pandas._libs.algos.take_1d_int64_int64}
#      7277    0.048    0.000    0.048    0.000 {pandas._libs.algos.take_2d_axis0_int32_int32}
#      7277    0.041    0.000    0.041    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#      7277    0.072    0.000    0.072    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#     14554    0.129    0.000    0.272    0.000 {pandas._libs.groupby.group_mean_float64}
#     14554    0.162    0.000    0.307    0.000 {pandas._libs.groupby.group_var_float64}
#     14554    0.081    0.000    0.081    0.000 {pandas._libs.lib.infer_dtype}
#     40000    0.031    0.000    0.089    0.000 {pandas._libs.lib.values_from_object}

# %% [markdown]
# #### The second step is to obtain the maps themselves from the fit-map-XY

# %%
ti = timeit(tsmap_from_fmap)
tsm = ti(fmxy)
# Out:
# Time spent in tsmap_from_fmap: 0.005877017974853516 s

# %%
tsm2 = ti(fmxy2)
# Out:
# Time spent in tsmap_from_fmap: 0.009534120559692383 s

# %% [markdown]
# #### Third step: select the corresponding map in the time series (in this case just one, ts=0)

# %%
am = amap_from_tsmap(tsm, 
                     ts = 0, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)

# %%
am2 = amap_from_tsmap(tsm2, 
                     ts = 0, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)

# %% [markdown]
# #### Am contains the maps in XY bins for the single time series (ts=0). We can now compute the map average, draw, etc:

# %%
amap_average(am)
# Out:
# ASectorMap(chi2=1.088193533674801, e0=9874.170179812814, lt=4190.17624437873, e0u=36.71099147123631, ltu=193.49106503627627, mapinfo=None)

# %%
amap_average(am2)
# Out:
# ASectorMap(chi2=1.0881926389184404, e0=9874.170359074935, lt=4190.1756530445, e0u=36.71080048600175, ltu=193.49031130279218, mapinfo=None)

# %% [markdown]
# #### Get rid of outlayers that distort mean and error

# %%
rmap = regularize_maps(am, erange=e_range, ltrange=lt_range)
# Out:
# 2019-02-16 00:19:59,733 | INFO :  set nans to average value of interval = 9500.0
# 2019-02-16 00:19:59,844 | INFO :  set nans to average value of interval = 3500.0

# %%
amap_average(rmap)
# Out:
# ASectorMap(chi2=1.088193533674801, e0=9874.170179812814, lt=4190.17624437873, e0u=36.71099147123631, ltu=193.49106503627627, mapinfo=None)

# %%
rmap2 = regularize_maps(am2, erange=e_range, ltrange=lt_range)
amap_average(rmap2)
# Out:
# 2019-02-16 00:20:23,561 | INFO :  set nans to average value of interval = 9500.0
# 2019-02-16 00:20:23,654 | INFO :  set nans to average value of interval = 3500.0
# ASectorMap(chi2=1.0881926389184404, e0=9874.170359074935, lt=4190.1756530445, e0u=36.71080048600175, ltu=193.49031130279218, mapinfo=None)

# %%
asm = relative_errors(rmap)

# %%
amv = amap_average(asm)
amv
# Out:
# ASectorMap(chi2=1.088193533674801, e0=9874.170179812814, lt=4190.17624437873, e0u=0.3771357622979298, ltu=4.627683463628203, mapinfo=None)

# %%
asm2 = relative_errors(rmap2)
amv2 = amap_average(asm2)
amv2
# Out:
# ASectorMap(chi2=1.0881926389184404, e0=9874.170359074935, lt=4190.1756530445, e0u=0.3771339376142995, ltu=4.627666041459519, mapinfo=None)

# %% [markdown]
# #### Draw the maps using default colormap

# %%
draw_xy_maps(asm,
            e0lims  = (7000, 14000),
            ltlims  = (3000, 6500),
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %%
draw_xy_maps(asm2,
            e0lims  = (7000, 14000),
            ltlims  = (3000, 6500),
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %% [markdown]
# #### The dark spots correspond to regions of low statistic, where the fits did not work. To avoid this effect, it is necessary to use more statistic for the XY maps.

# %%
asmAv = amap_replace_nan_by_mean(asm, amMean=amv)

# %%
amap_average(asmAv)
# Out:
# ASectorMap(chi2=1.092027751196735, e0=10023.81270148157, lt=4237.168731142595, e0u=0.370978396779412, ltu=4.582703902487272, mapinfo=None)

# %%
draw_xy_maps(asmAv,
            e0lims  = (7000, 14000),
            ltlims  = (3000, 6500),
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %%
asm = add_mapinfo(asmAv, krRanges.X, krRanges.Y, krNbins.X, krNbins.Y, run_number)

# %%
asm.mapinfo
# Out:
# xmin          -200
# xmax           200
# ymin          -200
# ymax           200
# nx             100
# ny             100
# run_number    6880
# dtype: int64

# %% [markdown]
# ### Save to file

# %%
write_maps(asm, filename=fn.emap_file_name)

# %% [markdown]
# ### Read back

# %%
fn.emap_file_name
# Out:
# '/Users/jjgomezcadenas/Projects/ICDATA/maps/kr_emap_xy_100_100_r_6880.h5'

# %%
emaps = read_maps(filename=fn.emap_file_name)

# %%
emaps.mapinfo
# Out:
# xmin          -200
# xmax           200
# ymin          -200
# ymax           200
# nx             100
# ny             100
# run_number    6880
# dtype: int64

# %%
draw_xy_maps(emaps,
            e0lims  = (7000, 14000),
            ltlims  = (3000, 6500),
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %% [markdown]
# ## Now check the corrections that can be achieved with the single maps

# %%
amap_average(emaps)
# Out:
# ASectorMap(chi2=1.092027751196735, e0=10023.81270148157, lt=4237.168731142595, e0u=0.370978396779412, ltu=4.582703902487272, mapinfo=None)

# %%
norm = amap_max(emaps)

# %%
norm
# Out:
# ASectorMap(chi2=2.890927484043513, e0=12154.263388668262, lt=5463.775387929789, e0u=0.8509179005148217, ltu=17.26301086231552, mapinfo=None)

# %% [markdown]
# #### E0 correction:

# %%
ti = timeit(e0_xy_correction)
E0 = ti(dst.S2e.values,
        dst.X.values,
        dst.Y.values,
        E0M = emaps.e0 / norm.e0, 
        xr  = krRanges.X,
        yr  = krRanges.Y,
        nx  = krNbins.X, 
        ny  = krNbins.Y)
# Out:
# Time spent in e0_xy_correction: 8.927151679992676 s

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(2, 1, 1)
nevt = h2(dst.Z, dst.S2e, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)
ax      = fig.add_subplot(2, 1, 2)
nevt = h2(dst.Z, E0, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

# %% [markdown]
# ## XY (single time) LT correction

# %%
ti = timeit(lt_xy_correction)
E = ti(E0, 
       dst.X.values, 
       dst.Y.values,
       dst.Z.values, 
       LTM = emaps.lt,
       xr  = krRanges.X,
       yr  = krRanges.Y,
       nx  = krNbins.X, 
       ny  = krNbins.Y)
# Out:
# Time spent in lt_xy_correction: 9.394202947616577 s

# %%
er = (5000,15000)

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(3, 1, 1)
nevt = h2(dst.Z, dst.S2e, 50, 50, krRanges.Z, er, 
           profile=True)
ax      = fig.add_subplot(3, 1, 2)
nevt = h2(dst.Z, E0, 50, 50, krRanges.Z, er, 
           profile=True)
ax      = fig.add_subplot(3, 1, 3)
nevt = h2(dst.Z, E, 50, 50, krRanges.Z, er, 
           profile=True)

# %%
nevt = h2d(dst.Z, E, 50, 50, krRanges.Z, (2000,14000),  
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %%
e_range = (0, 14500)
zrange = (10,550)
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(dst.Z, E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(E, nbins=100, range=(11000, 13000))
plot_fit_energy(fc)
print_fit_energy(fc)
# Out:
#   Fit was valid = True
#  Emu       = 12265.868118173164 +-0.2455404513384213
#  E sigma   = 247.93439875383777 +-0.18994514567298212
#  chi2    = 4.22684076281766
#  sigma E/E (FWHM)     (%) =4.75013942313849
#  sigma E/E (FWHM) Qbb (%) =0.6134897994054552

# %%
baseline = 11500
shift = 20
e1 = baseline - shift
e2 = baseline + shift
energy_time_profile(T, E, krNbins.T, krRanges.T, krTimes.timeStamps, 
                    erange=(e1, e2),
                    figsize=(12,6))

# %%
energy_X_profile(dst.R, E, xnbins = 100, xrange=(0,200), xlabel = 'R',
                 erange=(6500, 14000),  
                 figsize=(12,6))

# %%
energy_X_profile(phirad_to_deg(dst.Phi), E, xnbins = 100, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=(11000, 13500),  
                 figsize=(12,6))

# %%
energy_X_profile(dst.Z, E, xnbins = 100, xrange=(0,500), xlabel = 'Z',
                 erange=(11000, 13500),   
                 figsize=(12,6))

# %% [markdown]
# ### Select events in the region
#
# - R < 180
# - 10 < z < 550
# - 11000 < E < 13500

# %%
rrange = (0, 180)
sel = in_range(dst.R, *rrange) & in_range(dst.Z, *z_range) &  in_range(E, *e_range)

# %%
kse = kr_event(dst, DT, E, dst.S2q, sel)  # kse = krypton selected event

# %% [markdown]
# ### Repeat profles

# %%
energy_X_profile(kse.R, kse.E, xnbins = 100, xrange=(0,200), xlabel = 'R',
                 erange=e_range,  
                 figsize=(12,6))

# %%
energy_X_profile(phirad_to_deg(kse.Phi), kse.E, xnbins = 100, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=e_range,  
                 figsize=(12,6))

# %%
energy_X_profile(kse.Z, kse.E, xnbins = 100, xrange=zrange, xlabel = 'Z',
                 erange=e_range,   
                 figsize=(12,6))

# %%
energy_X_profile(kse.DT, kse.E, xnbins = 100, xrange=(kse.DT[0], kse.DT[-1]), xlabel = 'DT',
                 erange=e_range,   
                 figsize=(12,6))

# %% [markdown]
# #### Everything is flat. No need for further corrections.

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(kse.Z, kse.E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(kse.E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(kse.E, nbins=100, range=(10000, 13000))
plot_fit_energy(fc)
print_fit_energy(fc)
# Out:
#   Fit was valid = True
#  Emu       = 12268.548744998749 +-0.2576839114243094
#  E sigma   = 235.88688085948968 +-0.19750736569567998
#  chi2    = 3.411336077426142
#  sigma E/E (FWHM)     (%) =4.518335310407224
#  sigma E/E (FWHM) Qbb (%) =0.5835518447576095

# %%
Ri = (50, 100,150,180)
Zi = (50, 100,200,300,500)

FC, FCE = resolution_r_z(Ri, Zi, kse.R, kse.Z, kse.E,
                    enbins = 50,
                    erange = (10500,13000),
                    ixy = (5,4),
                    fdraw  = True,
                    fprint = False,
                    figsize = (18,10))

# %%
plot_resolution_r_z(Ri, Zi, FC, FCE, r_range=(0,10))
